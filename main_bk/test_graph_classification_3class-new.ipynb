# %%
# %matplotlib inline

# %%
import dgl
def build_circuit_graph_undirected(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(src, dst)
    g.add_edges(dst, src)
    return g

def build_circuit_graph_directed_sd(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(src, dst)
    return g

def build_circuit_graph_directed_ds(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(dst, src)
    return g

# %%
import os
import matplotlib.pyplot as plt
import networkx as nx
import csv
import numpy as np
dir = 'training_data'

trainset=[]
labels=[]
#for filename in os.listdir(dir):
for idx in range(4,25):
    node_list=[]
    edge_list=[]
    label_list=[]
    node_list2=[]
    edge_list2=[]
    label_list2=[]
    node_list3=[]
    edge_list3=[]
    label_list3=[]
    for j in ["node_list","edge_list","graph_label"]:
        filename = "rca_"+str(idx)+"bit"+j+'.csv'
        filename2 = "cla_"+str(idx)+"bit"+j+'.csv'
        filename3 = "csa_"+str(idx)+"bit"+j+'.csv'
        
        if(filename.find("node_list")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                node_list = list(reader)
                
        if(filename.find("edge_list")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list = list(reader)
        if(filename.find("graph_label")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                label_list = list(reader)
        if(filename.find("gate_type")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type = list(reader)
        
        if(filename2.find("node_list")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                node_list2 = list(reader)
                
        if(filename2.find("edge_list")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list2 = list(reader)
        if(filename2.find("graph_label")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                label_list2 = list(reader)
        if(filename2.find("gate_type")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type2 = list(reader)
        
        if(filename3.find("node_list")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                node_list3 = list(reader)
                
        if(filename3.find("edge_list")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list3 = list(reader)
        if(filename3.find("graph_label")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                label_list3 = list(reader)
        if(filename3.find("gate_type")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type3 = list(reader)
    #create dgl graph
    g=build_circuit_graph_undirected(node_list,edge_list)
    trainset.append(g)
    labels.append(label_list[0])
    g2=build_circuit_graph_undirected(node_list2,edge_list2)
    trainset.append(g2)
    labels.append(label_list2[0])
    g3=build_circuit_graph_undirected(node_list3,edge_list3)
    trainset.append(g3)
    labels.append(label_list3[0])





for i in labels:
    i[0] = int(i[0])

print(labels)
# A dataset with 80 samples, each graph is
# of size [10, 20]
#dataset = MiniGCDataset(80, 10, 20)
#print(dataset[0])
graph = trainset[1]
label=labels[0][0]

fig, ax = plt.subplots()
nx.draw(graph.to_networkx(), ax=ax)
ax.set_title('Class: {:f}'.format(label))
plt.show()
# Out:
# [[1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2]]

# %% [markdown]
# ### Apply random shuffle to training set

# %%
##apply random shuffle on the trainset    
randomize = np.arange(len(trainset))
np.random.shuffle(randomize)
labels_shuffled=[]
trainset_shuffled=[]
for i in range (len(randomize)):
    labels_shuffled.append(labels[randomize[i]])
    trainset_shuffled.append(trainset[randomize[i]])
print(trainset_shuffled)
print(labels_shuffled)
# Out:
# [DGLGraph(num_nodes=84, num_edges=272,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=192, num_edges=642,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=553, num_edges=2066,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=209, num_edges=700,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=285, num_edges=952,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=124, num_edges=448,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=228, num_edges=764,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=253, num_edges=844,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=304, num_edges=1024,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=162, num_edges=536,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=459, num_edges=1706,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=305, num_edges=1020,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=352, num_edges=1302,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=118, num_edges=394,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=579, num_edges=2154,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=150, num_edges=536,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=364, num_edges=1220,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=201, num_edges=668,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=472, num_edges=1750,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=326, num_edges=1094,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=173, num_edges=580,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=137, num_edges=492,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=247, num_edges=826,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=263, num_edges=882,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=446, num_edges=1662,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=175, num_edges=580,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=240, num_edges=800,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=365, num_edges=1346,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=266, num_edges=888,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=594, num_edges=2206,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=214, num_edges=712,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=258, num_edges=942,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=227, num_edges=756,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=382, num_edges=1280,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=318, num_edges=1064,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=136, num_edges=448,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=149, num_edges=492,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=422, num_edges=1410,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=58, num_edges=184,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=97, num_edges=316,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=273, num_edges=994,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=292, num_edges=976,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=136, num_edges=456,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=403, num_edges=1348,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=188, num_edges=624,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=344, num_edges=1154,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=67, num_edges=218,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=439, num_edges=1468,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=339, num_edges=1258,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=245, num_edges=898,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=57, num_edges=182,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=279, num_edges=932,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=110, num_edges=360,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=85, num_edges=278,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=154, num_edges=516,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=100, num_edges=334,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=487, num_edges=1802,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=380, num_edges=1398,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=232, num_edges=854,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=165, num_edges=588,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=123, num_edges=404,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=71, num_edges=228,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=566, num_edges=2110,
#          ndata_schemes={}
#          edata_schemes={})]
# [[1], [0], [2], [0], [0], [2], [0], [1], [0], [1], [2], [1], [2], [0], [2], [2], [0], [1], [2], [0], [0], [2], [0], [0], [2], [1], [1], [2], [1], [2], [1], [2], [1], [0], [1], [1], [1], [0], [1], [1], [2], [1], [0], [0], [1], [0], [0], [0], [2], [2], [2], [1], [1], [0], [0], [0], [2], [2], [2], [2], [1], [1], [2]]

# %%
import dgl

def collate(samples):
    # The input `samples` is a list of pairs
    #  (graph, label).
    graphs, labels = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs)
    return batched_graph, torch.tensor(labels)

# %%
import dgl.function as fn
import torch
import torch.nn as nn


# Sends a message of node feature h.
msg = fn.copy_src(src='h', out='m')

def reduce(nodes):
    """Take an average over all neighbor node features hu and use it to
    overwrite the original node feature."""
    accum = torch.mean(nodes.mailbox['m'], 1)
    return {'h': accum}

class NodeApplyModule(nn.Module):
    """Update the node feature hv with ReLU(Whv+b)."""
    def __init__(self, in_feats, out_feats, activation):
        super(NodeApplyModule, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        self.activation = activation

    def forward(self, node):
        h = self.linear(node.data['h'])
        h = self.activation(h)
        return {'h' : h}

class GCN(nn.Module):
    def __init__(self, in_feats, out_feats, activation):
        super(GCN, self).__init__()
        self.apply_mod = NodeApplyModule(in_feats, out_feats, activation)

    def forward(self, g, feature):
        # Initialize the node features with h.
        g.ndata['h'] = feature
        g.update_all(msg, reduce)
        g.apply_nodes(func=self.apply_mod)
        return g.ndata.pop('h')

# %% [markdown]
# Readout and classification
# --------------------------
# For this demonstration, consider initial node features to be their degrees.
# After two rounds of graph convolution, perform a graph readout by averaging
# over all node features for each graph in the batch.
#
# \begin{align}h_g=\frac{1}{|\mathcal{V}|}\sum_{v\in\mathcal{V}}h_{v}\end{align}
#
# In DGL, :func:`dgl.mean_nodes` handles this task for a batch of
# graphs with variable size. You then feed the graph representations into a
# classifier with one linear layer to obtain pre-softmax logits.

# %%
import torch.nn.functional as F


class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()

        self.layers = nn.ModuleList([
            GCN(in_dim, hidden_dim, F.relu),
            GCN(hidden_dim, hidden_dim, F.relu)])
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g):
        # For undirected graphs, in_degree is the same as
        # out_degree.
        h = g.in_degrees().view(-1, 1).float()
        for conv in self.layers:
            h = conv(g, h)
        g.ndata['h'] = h
        hg = dgl.mean_nodes(g, 'h')
        return self.classify(hg)

# %% [markdown]
# Setup and training
# ------------------
# Create a synthetic dataset of $400$ graphs with $10$ ~
# $20$ nodes. $320$ graphs constitute a training set and
# $80$ graphs constitute a test set.

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

# Create training and test sets.
# trainset = MiniGCDataset(320, 10, 20)
# testset = MiniGCDataset(80, 10, 20)
print(trainset)
# Out:
# [DGLGraph(num_nodes=58, num_edges=184,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=67, num_edges=218,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=57, num_edges=182,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=71, num_edges=228,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=85, num_edges=278,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=124, num_edges=448,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=84, num_edges=272,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=100, num_edges=334,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=137, num_edges=492,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=97, num_edges=316,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=118, num_edges=394,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=150, num_edges=536,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=110, num_edges=360,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=136, num_edges=456,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=165, num_edges=588,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=123, num_edges=404,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=154, num_edges=516,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=232, num_edges=854,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=136, num_edges=448,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=173, num_edges=580,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=245, num_edges=898,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=149, num_edges=492,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=192, num_edges=642,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=258, num_edges=942,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=162, num_edges=536,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=209, num_edges=700,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=273, num_edges=994,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=175, num_edges=580,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=228, num_edges=764,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=339, num_edges=1258,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=188, num_edges=624,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=247, num_edges=826,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=352, num_edges=1302,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=201, num_edges=668,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=263, num_edges=882,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=365, num_edges=1346,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=214, num_edges=712,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=285, num_edges=952,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=380, num_edges=1398,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=227, num_edges=756,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=304, num_edges=1024,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=446, num_edges=1662,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=240, num_edges=800,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=326, num_edges=1094,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=459, num_edges=1706,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=253, num_edges=844,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=344, num_edges=1154,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=472, num_edges=1750,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=266, num_edges=888,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=364, num_edges=1220,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=487, num_edges=1802,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=279, num_edges=932,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=382, num_edges=1280,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=553, num_edges=2066,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=292, num_edges=976,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=403, num_edges=1348,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=566, num_edges=2110,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=305, num_edges=1020,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=422, num_edges=1410,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=579, num_edges=2154,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=318, num_edges=1064,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=439, num_edges=1468,
#          ndata_schemes={}
#          edata_schemes={}), DGLGraph(num_nodes=594, num_edges=2206,
#          ndata_schemes={}
#          edata_schemes={})]

# %%
# Use PyTorch's DataLoader and the collate function
# defined before.
data_loader = DataLoader(trainset, batch_size=2, shuffle=True,
                         collate_fn=collate)
print(data_loader)
# Create model
#model = Classifier(1, 256, trainset.num_classes)
model = Classifier(1, 256, 3)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
model.train()

labels_shuffled = torch.LongTensor(labels_shuffled)

epoch_losses = []
for epoch in range(80):
    epoch_loss = 0
    for iter, bg in enumerate(trainset_shuffled):
        prediction=torch.zeros(1,3,dtype=torch.float64)
        prediction[0] = model(bg)
        
        loss = loss_func(prediction, labels_shuffled[iter])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
    epoch_loss /= (iter + 1)
    print('Epoch {}, loss {:.4f}'.format(epoch, epoch_loss))
    epoch_losses.append(epoch_loss)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fe20f707748>
# Epoch 0, loss 1.2849
# Epoch 1, loss 1.1810
# Epoch 2, loss 1.1108
# Epoch 3, loss 1.1085
# Epoch 4, loss 1.0976
# Epoch 5, loss 1.0916
# Epoch 6, loss 1.0908
# Epoch 7, loss 1.0828
# Epoch 8, loss 1.0749
# Epoch 9, loss 1.0645
# Epoch 10, loss 1.0410
# Epoch 11, loss 1.0556
# Epoch 12, loss 0.9988
# Epoch 13, loss 0.9783
# Epoch 14, loss 0.9501
# Epoch 15, loss 0.9212
# Epoch 16, loss 0.8833
# Epoch 17, loss 0.8441
# Epoch 18, loss 0.8073
# Epoch 19, loss 0.7666
# Epoch 20, loss 0.7285
# Epoch 21, loss 0.6924
# Epoch 22, loss 0.6590
# Epoch 23, loss 0.6277
# Epoch 24, loss 0.5974
# Epoch 25, loss 0.5696
# Epoch 26, loss 0.5428
# Epoch 27, loss 0.5236
# Epoch 28, loss 0.5018
# Epoch 29, loss 0.4817
# Epoch 30, loss 0.4644
# Epoch 31, loss 0.4492
# Epoch 32, loss 0.4335
# Epoch 33, loss 0.4180
# Epoch 34, loss 0.4050
# Epoch 35, loss 0.3936
# Epoch 36, loss 0.3831
# Epoch 37, loss 0.3722
# Epoch 38, loss 0.3635
# Epoch 39, loss 0.3557
# Epoch 40, loss 0.3478
# Epoch 41, loss 0.3413
# Epoch 42, loss 0.3356
# Epoch 43, loss 0.3306
# Epoch 44, loss 0.3246
# Epoch 45, loss 0.3202
# Epoch 46, loss 0.3148
# Epoch 47, loss 0.3112
# Epoch 48, loss 0.3073
# Epoch 49, loss 0.3043
# Epoch 50, loss 0.3015
# Epoch 51, loss 0.2988
# Epoch 52, loss 0.2961
# Epoch 53, loss 0.2938
# Epoch 54, loss 0.2919
# Epoch 55, loss 0.2901
# Epoch 56, loss 0.2884
# Epoch 57, loss 0.2871
# Epoch 58, loss 0.2857
# Epoch 59, loss 0.2844
# Epoch 60, loss 0.2835
# Epoch 61, loss 0.2824
# Epoch 62, loss 0.2817
# Epoch 63, loss 0.2808
# Epoch 64, loss 0.2802
# Epoch 65, loss 0.2794
# Epoch 66, loss 0.2788
# Epoch 67, loss 0.2783
# Epoch 68, loss 0.2775
# Epoch 69, loss 0.2769
# Epoch 70, loss 0.2766
# Epoch 71, loss 0.2763
# Epoch 72, loss 0.2755
# Epoch 73, loss 0.2753
# Epoch 74, loss 0.2752
# Epoch 75, loss 0.2748
# Epoch 76, loss 0.2746
# Epoch 77, loss 0.2744
# Epoch 78, loss 0.2743
# Epoch 79, loss 0.2742

# %% [markdown]
# The learning curve of a run is presented below.

# %%
plt.title('cross entropy averaged over minibatches')
plt.plot(epoch_losses)
plt.show()

# %% [markdown]
# The trained model is evaluated on the test set created. To deploy
# the tutorial, restrict the running time to get a higher
# accuracy ($80$ % ~ $90$ %) than the ones printed below.

# %%
print(model.layers[0].apply_mod.linear.weight.size())
print(model.layers[1].apply_mod.linear.weight.size())
model.classify.weight.size()
# Out:
# torch.Size([256, 1])
# torch.Size([256, 256])
# torch.Size([3, 256])

# %% [markdown]
# ### Get Testset data

# %%
testset = []
test_labels = []
test_dir = 'test_data'
for idx in range(25,64):
    node_list=[]
    edge_list=[]
    label_list=[]
    node_list2=[]
    edge_list2=[]
    label_list2=[]
    node_list3=[]
    edge_list3=[]
    label_list3=[]
    for j in ["node_list","edge_list","graph_label"]:
        filename = "rca_"+str(idx)+"bit"+j+'.csv'
        filename2 = "cla_"+str(idx)+"bit"+j+'.csv'
        filename3 = "csa_"+str(idx)+"bit"+j+'.csv'
        
        if(filename.find("node_list")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                node_list = list(reader)
                
        if(filename.find("edge_list")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list = list(reader)
        if(filename.find("graph_label")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                label_list = list(reader)
        if(filename.find("gate_type")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type = list(reader)
        
        if(filename2.find("node_list")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                node_list2 = list(reader)
                
        if(filename2.find("edge_list")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list2 = list(reader)
        if(filename2.find("graph_label")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                label_list2 = list(reader)
        if(filename2.find("gate_type")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type2 = list(reader)
        if(filename3.find("node_list")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                node_list3 = list(reader)
                
        if(filename3.find("edge_list")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list3 = list(reader)
        if(filename3.find("graph_label")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                label_list3 = list(reader)
        if(filename3.find("gate_type")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type3 = list(reader)
    #create dgl graph
    g=build_circuit_graph_undirected(node_list,edge_list)
    testset.append(g)
    test_labels.append(label_list[0])
    g2=build_circuit_graph_undirected(node_list2,edge_list2)
    testset.append(g2)
    test_labels.append(label_list2[0])
    g3=build_circuit_graph_undirected(node_list3,edge_list3)
    testset.append(g3)
    test_labels.append(label_list3[0])

for i in test_labels:
    i[0] = int(i[0])

print(test_labels)
# Out:
# [[1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2], [1], [0], [2]]

# %%
##apply random shuffle on the testset    
randomize = np.arange(len(testset))
np.random.shuffle(randomize)
testset_shuffled=[]
test_labels_shuffled=[]
for i in range (len(randomize)):
    test_labels_shuffled.append(test_labels[randomize[i]])
    testset_shuffled.append(testset[randomize[i]])

# %%
model.eval()
test_bg = dgl.batch(testset_shuffled)
test_labels = torch.tensor(test_labels_shuffled).float().view(-1, 1)
probs_Y = torch.softmax(model(test_bg), 1)


sampled_Y = torch.multinomial(probs_Y, 1)
argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)
print('Accuracy of sampled predictions on the test set: {:.4f}%'.format(
    (test_labels == sampled_Y.float()).sum().item() / len(test_labels) * 100))
print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
    (test_labels == argmax_Y.float()).sum().item() / len(test_labels) * 100))

zip(model(test_bg),(test_labels))
for i1,i2 in zip(probs_Y,(test_labels)):
    print(i1,i2)
# print(torch.max(probs_Y, 1))
# Out:
# Accuracy of sampled predictions on the test set: 91.4530%
# Accuracy of argmax predictions on the test set: 100.000000%
# tensor([1.9311e-04, 9.6770e-16, 9.9981e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([8.4637e-02, 9.1507e-01, 2.9168e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([0.8850, 0.0111, 0.1039], grad_fn=<SelectBackward>) tensor([0.])
# tensor([1.1370e-02, 3.6169e-10, 9.8863e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([4.9678e-04, 2.1496e-14, 9.9950e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([8.2597e-04, 1.1140e-13, 9.9917e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([3.5849e-04, 6.9850e-15, 9.9964e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([0.8971, 0.0163, 0.0866], grad_fn=<SelectBackward>) tensor([0.])
# tensor([8.3439e-02, 9.1628e-01, 2.8564e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([8
-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([0.8950, 0.0154, 0.0896], grad_fn=<SelectBackward>) tensor([0.])
# tensor([1.8683e-04, 8.9068e-16, 9.9981e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([0.8925, 0.0139, 0.0936], grad_fn=<SelectBackward>) tensor([0.])
# tensor([8.4814e-02, 9.1489e-01, 2.9257e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([8.3864e-02, 9.1585e-01, 2.8778e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([0.8881, 0.0122, 0.0998], grad_fn=<SelectBackward>) tensor([0.])
# tensor([0.8971, 0.0161, 0.0868], grad_fn=<SelectBackward>) tensor([0.])
# tensor([2.7772e-04, 3.0587e-15, 9.9972e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([1.5438e-03, 8.0104e-13, 9.9846e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([1.0410e-03, 2.1698e-13, 9.9896e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([8.4133e-02, 9.1558e-01, 2.8913e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([1.0710e-03, 2.5860e-13, 9.9893e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([0.8867, 0.0117, 0.1016], grad_fn=<SelectBackward>) tensor([0.])
# tensor([0.8948, 0.0151, 0.0901], grad_fn=<SelectBackward>) tensor([0.])
# tensor([0.8970, 0.0167, 0.0863], grad_fn=<SelectBackward>) tensor([0.])
# tensor([0.8972, 0.0167, 0.0861], grad_fn=<SelectBackward>) tensor([0.])
# tensor([2.3794e-04, 1.9588e-15, 9.9976e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([8.3662e-02, 9.1605e-01, 2.8677e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([0.8954, 0.0152, 0.0895], grad_fn=<SelectBackward>) tensor([0.])
# tensor([8.4972e-02, 9.1473e-01, 2.9337e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([8.4698e-02, 9.1501e-01, 2.9199e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([0.9014, 0.0207, 0.0779], grad_fn=<SelectBackward>) tensor([0.])
# tensor([8.4868e-02, 9.1484e-01, 2.9285e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([6.0217e-04, 3.7441e-14, 9.9940e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([8.5283e-02, 9.1442e-01, 2.9495e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([0.8990, 0.0176, 0.0834], grad_fn=<SelectBackward>) tensor([0.])
# tensor([8.2425e-02, 9.1729e-01, 2.8058e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([8.2760e-02, 9.1696e-01, 2.8225e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([1.1579e-03, 3.1916e-13, 9.9884e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([7.8900e-04, 8.9189e-14, 9.9921e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([1.8826e-03, 1.4405e-12, 9.9812e-01], grad_fn=<SelectBackward>) tensor([2.])

# %%
import tsne

#m = trainset[0].adjacency_matrix()
m = model(test_bg).data.numpy()

# %%
Y = tsne.tsne(m, 2, 30)

# %%
print(Y)

# %%
fig, axs = plt.subplots(2,2)


color = test_labels*125/255
for i in range (len(test_labels)):
    axs[0,0].scatter(m[i,0],m[i,1],color=(0,color[i],0))
    axs[0,1].scatter(Y[i,0],Y[i,1],color=(0,color[i],0))
    

    
plt.show()

# %% [markdown]
# ### test

# %%
testset = []
test_labels = []
test_dir = 'test_data'

testing_idx=[]
idx=12
node_list=[]
edge_list=[]
label_list=[]
node_list2=[]
edge_list2=[]
label_list2=[]
node_list3=[]
edge_list3=[]
label_list3=[]
for j in ["node_list","edge_list","graph_label"]:
    filename = "rca_"+str(idx)+"bit"+j+'.csv'
    filename2 = "cla_"+str(idx)+"bit"+j+'.csv'
    filename3 = "csa_"+str(idx)+"bit"+j+'.csv'
    filename4 = "CSkipA_"+str(idx)+"bit"+j+'.csv'
    
    if(filename.find("node_list")>=0):
        with open(test_dir+'/'+filename, 'rt') as fh:
            reader=csv.reader(fh)
            node_list = list(reader)
            
    if(filename.find("edge_list")>=0):
        with open(test_dir+'/'+filename, 'rt') as fh:
            reader=csv.reader(fh)
            edge_list = list(reader)
    if(filename.find("graph_label")>=0):
        with open(test_dir+'/'+filename, 'rt') as fh:
            reader=csv.reader(fh)
            label_list = list(reader)
    if(filename.find("gate_type")>=0):
        with open(test_dir+'/'+filename, 'rt') as fh:
            reader=csv.reader(fh)
            gate_type = list(reader)
    
    if(filename2.find("node_list")>=0):
        with open(test_dir+'/'+filename2, 'rt') as fh:
            reader=csv.reader(fh)
            node_list2 = list(reader)
            
    if(filename2.find("edge_list")>=0):
        with open(test_dir+'/'+filename2, 'rt') as fh:
            reader=csv.reader(fh)
            edge_list2 = list(reader)
    if(filename2.find("graph_label")>=0):
        with open(test_dir+'/'+filename2, 'rt') as fh:
            reader=csv.reader(fh)
            label_list2 = list(reader)
    if(filename2.find("gate_type")>=0):
        with open(test_dir+'/'+filename2, 'rt') as fh:
            reader=csv.reader(fh)
            gate_type2 = list(reader)
    if(filename3.find("node_list")>=0):
        with open(test_dir+'/'+filename3, 'rt') as fh:
            reader=csv.reader(fh)
            node_list3 = list(reader)
            
    if(filename3.find("edge_list")>=0):
        with open(test_dir+'/'+filename3, 'rt') as fh:
            reader=csv.reader(fh)
            edge_list3 = list(reader)
    if(filename3.find("graph_label")>=0):
        with open(test_dir+'/'+filename3, 'rt') as fh:
            reader=csv.reader(fh)
            label_list3 = list(reader)
    if(filename3.find("gate_type")>=0):
        with open(test_dir+'/'+filename3, 'rt') as fh:
            reader=csv.reader(fh)
            gate_type3 = list(reader)
    if(filename4.find("node_list")>=0):
        with open(dir+'/'+filename4, 'rt') as fh:
            reader=csv.reader(fh)
            node_list4 = list(reader)
            
    if(filename4.find("edge_list")>=0):
        with open(dir+'/'+filename4, 'rt') as fh:
            reader=csv.reader(fh)
            edge_list4 = list(reader)
    if(filename4.find("graph_label")>=0):
        with open(dir+'/'+filename4, 'rt') as fh:
            reader=csv.reader(fh)
            label_list4 = list(reader)
    if(filename4.find("gate_type")>=0):
        with open(dir+'/'+filename4, 'rt') as fh:
            reader=csv.reader(fh)
            gate_type4 = list(reader)
#create dgl graph
g=build_circuit_graph_undirected(node_list,edge_list)
testset.append(g)
test_labels.append(label_list[0])
g2=build_circuit_graph_undirected(node_list2,edge_list2)
testset.append(g2)
test_labels.append(label_list2[0])
g3=build_circuit_graph_undirected(node_list3,edge_list3)
testset.append(g3)
test_labels.append(label_list3[0])


for i in test_labels:
    i[0] = int(i[0])

print(test_labels)
# Out:
# [[1], [0], [2], [3]]

# %%
model.eval()
test_bg = dgl.batch(testset)
test_labels = torch.tensor(test_labels).float().view(-1, 1)
probs_Y = torch.softmax(model(test_bg), 1)


sampled_Y = torch.multinomial(probs_Y, 1)
argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)
print('Accuracy of sampled predictions on the test set: {:.4f}%'.format(
    (test_labels == sampled_Y.float()).sum().item() / len(test_labels) * 100))
print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
    (test_labels == argmax_Y.float()).sum().item() / len(test_labels) * 100))

zip(model(test_bg),(test_labels))
for i1,i2 in zip(probs_Y,(test_labels)):
    print(i1,i2)
# print(torch.max(probs_Y, 1))
# Out:
# Accuracy of sampled predictions on the test set: 50.0000%
# Accuracy of argmax predictions on the test set: 75.000000%
# tensor([7.5535e-02, 9.2422e-01, 2.4693e-04], grad_fn=<SelectBackward>) tensor([1.])
# tensor([0.9040, 0.0270, 0.0690], grad_fn=<SelectBackward>) tensor([0.])
# tensor([9.6453e-02, 2.6397e-07, 9.0355e-01], grad_fn=<SelectBackward>) tensor([2.])
# tensor([0.8672, 0.0997, 0.0331], grad_fn=<SelectBackward>) tensor([3.])
