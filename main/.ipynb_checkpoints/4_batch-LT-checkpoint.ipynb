# %%
# %matplotlib inline

# %% [markdown]
# .. currentmodule:: dgl
#
# Graph Classification Tutorial
# =============================
#
# **Author**: `Mufei Li <https://github.com/mufeili>`_,
# `Minjie Wang <https://jermainewang.github.io/>`_,
# `Zheng Zhang <https://shanghai.nyu.edu/academics/faculty/directory/zheng-zhang>`_.
#
# In this tutorial, you learn how to use DGL to batch multiple graphs of variable size and shape. The
# tutorial also demonstrates training a graph neural network for a simple graph classification task.
#
# Graph classification is an important problem
# with applications across many fields, such as bioinformatics, chemoinformatics, social
# network analysis, urban computing, and cybersecurity. Applying graph neural
# networks to this problem has been a popular approach recently. This can be seen in the following reserach references:
# `Ying et al., 2018 <https://arxiv.org/abs/1806.08804>`_,
# `Cangea et al., 2018 <https://arxiv.org/abs/1811.01287>`_,
# `Knyazev et al., 2018 <https://arxiv.org/abs/1811.09595>`_,
# `Bianchi et al., 2019 <https://arxiv.org/abs/1901.01343>`_,
# `Liao et al., 2019 <https://arxiv.org/abs/1901.01484>`_,
# `Gao et al., 2019 <https://openreview.net/forum?id=HJePRoAct7>`_).

# %% [markdown]
# Simple graph classification task
# --------------------------------
# In this tutorial, you learn how to perform batched graph classification
# with DGL. The example task objective is to classify eight types of topologies shown here.
#
# ![](https://s3.us-east-2.amazonaws.com/dgl.ai/tutorial/batch/dataset_overview.png)
#
#     :align: center
#
# Implement a synthetic dataset :class:`data.MiniGCDataset` in DGL. The dataset has eight
# different types of graphs and each class has the same number of graph samples.

# %%
# from dgl.data import MiniGCDataset
# import matplotlib.pyplot as plt
# import networkx as nx
# # A dataset with 80 samples, each graph is
# # of size [10, 20]
# dataset = MiniGCDataset(80, 10, 20)
# print(dataset[0])
# graph, label = dataset[0]
# fig, ax = plt.subplots()
# nx.draw(graph.to_networkx(), ax=ax)
# ax.set_title('Class: {:d}'.format(label))
# plt.show()

# %%
import dgl

def collate(samples):
    # The input `samples` is a list of pairs
    #  (graph, label).
    graphs, labels = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs)
    return batched_graph, torch.tensor(labels)

# %% [markdown]
# The return type of :func:`dgl.batch` is still a graph. In the same way,
# a batch of tensors is still a tensor. This means that any code that works
# for one graph immediately works for a batch of graphs. More importantly,
# because DGL processes messages on all nodes and edges in parallel, this greatly
# improves efficiency.
#
# Graph classifier
# ----------------
# Graph classification proceeds as follows.
#
# ![](https://s3.us-east-2.amazonaws.com/dgl.ai/tutorial/batch/graph_classifier.png)
#
#
# From a batch of graphs, perform message passing and graph convolution
# for nodes to communicate with others. After message passing, compute a
# tensor for graph representation from node (and edge) attributes. This step might
# be called readout or aggregation. Finally, the graph
# representations are fed into a classifier $g$ to predict the graph labels.
#
# Graph convolution
# -----------------
# The graph convolution operation is basically the same as that for graph convolutional network (GCN). To learn more,
# see the GCN `tutorial <https://docs.dgl.ai/tutorials/models/1_gnn/1_gcn.html>`_). The only difference is
# that we replace $h_{v}^{(l+1)} = \text{ReLU}\left(b^{(l)}+\sum_{u\in\mathcal{N}(v)}h_{u}^{(l)}W^{(l)}\right)$
# by
# $h_{v}^{(l+1)} = \text{ReLU}\left(b^{(l)}+\frac{1}{|\mathcal{N}(v)|}\sum_{u\in\mathcal{N}(v)}h_{u}^{(l)}W^{(l)}\right)$
#
# The replacement of summation by average is to balance nodes with different
# degrees. This gives a better performance for this experiment.
#
# The self edges added in the dataset initialization allows you to
# include the original node feature $h_{v}^{(l)}$ when taking the average.

# %%
import dgl.function as fn
import torch
import torch.nn as nn


# Sends a message of node feature h.
msg = fn.copy_src(src='h', out='m')

def reduce(nodes):
    """Take an average over all neighbor node features hu and use it to
    overwrite the original node feature."""
    accum = torch.mean(nodes.mailbox['m'], 1)
    return {'h': accum}

class NodeApplyModule(nn.Module):
    """Update the node feature hv with ReLU(Whv+b)."""
    def __init__(self, in_feats, out_feats, activation):
        super(NodeApplyModule, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        self.activation = activation

    def forward(self, node):
        h = self.linear(node.data['h'])
        h = self.activation(h)
        return {'h' : h}

class GCN(nn.Module):
    def __init__(self, in_feats, out_feats, activation):
        super(GCN, self).__init__()
        self.apply_mod = NodeApplyModule(in_feats, out_feats, activation)

    def forward(self, g, feature):
        # Initialize the node features with h.
        g.ndata['h'] = feature
        g.update_all(msg, reduce)
        g.apply_nodes(func=self.apply_mod)
        return g.ndata.pop('h')

# %% [markdown]
# Readout and classification
# --------------------------
# For this demonstration, consider initial node features to be their degrees.
# After two rounds of graph convolution, perform a graph readout by averaging
# over all node features for each graph in the batch.
#
# \begin{align}h_g=\frac{1}{|\mathcal{V}|}\sum_{v\in\mathcal{V}}h_{v}\end{align}
#
# In DGL, :func:`dgl.mean_nodes` handles this task for a batch of
# graphs with variable size. You then feed the graph representations into a
# classifier with one linear layer to obtain pre-softmax logits.

# %%
import torch.nn.functional as F


class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()

        self.layers = nn.ModuleList([
            GCN(in_dim, hidden_dim, F.relu),
            GCN(hidden_dim, hidden_dim, F.relu)])
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g):
        # For undirected graphs, in_degree is the same as
        # out_degree.
        h = g.in_degrees().view(-1, 1).float()
        for conv in self.layers:
            h = conv(g, h)
        g.ndata['h'] = h
        hg = dgl.mean_nodes(g, 'h')
        return self.classify(hg)

# %% [markdown]
# ## Rewrite Graph Generation Class

# %%
"""A mini synthetic dataset for graph classification benchmark."""
import math
import networkx as nx
import numpy as np

from dgl.graph import DGLGraph

__all__ = ['MiniGCDataset']

class MiniGCDataset_4c(object):
    """The dataset class.

    The datset contains 8 different types of graphs.

    * class 0 : cycle graph
    * class 1 : star graph
    * class 2 : wheel graph
    * class 3 : lollipop graph

    .. note::
        This dataset class is compatible with pytorch's :class:`Dataset` class.

    Parameters
    ----------
    num_graphs: int
        Number of graphs in this dataset.
    min_num_v: int
        Minimum number of nodes for graphs
    max_num_v: int
        Maximum number of nodes for graphs
    """
    def __init__(self, num_graphs, min_num_v, max_num_v):
        super(MiniGCDataset_4c, self).__init__()
        self.num_graphs = num_graphs
        self.min_num_v = min_num_v
        self.max_num_v = max_num_v
        self.graphs = []
        self.labels = []
        self._generate()

    def __len__(self):
        """Return the number of graphs in the dataset."""
        return len(self.graphs)


    def __getitem__(self, idx):
        """Get the i^th sample.

        Paramters
        ---------
        idx : int
            The sample index.

        Returns
        -------
        (dgl.DGLGraph, int)
            The graph and its label.
        """
        return self.graphs[idx], self.labels[idx]


    @property
    def num_classes(self):
        """Number of classes."""
        return 4

    def _generate(self):
        self._gen_cycle(self.num_graphs // 4)
        self._gen_star(self.num_graphs // 4)
        self._gen_wheel(self.num_graphs // 4)
        self._gen_lollipop(self.num_graphs - len(self.graphs))
#         self._gen_lollipop(self.num_graphs // 8)
#         self._gen_hypercube(self.num_graphs // 8)
#         self._gen_grid(self.num_graphs // 8)
#         self._gen_clique(self.num_graphs // 8)
#         self._gen_circular_ladder(self.num_graphs - len(self.graphs))
        # preprocess
        for i in range(self.num_graphs):
            self.graphs[i] = DGLGraph(self.graphs[i])
            # add self edges
            nodes = self.graphs[i].nodes()
            self.graphs[i].add_edges(nodes, nodes)

    def _gen_cycle(self, n):
        for _ in range(n):
            num_v = np.random.randint(self.min_num_v, self.max_num_v)
            g = nx.cycle_graph(num_v)
            self.graphs.append(g)
            self.labels.append(0)

    def _gen_star(self, n):
        for _ in range(n):
            num_v = np.random.randint(self.min_num_v, self.max_num_v)
            # nx.star_graph(N) gives a star graph with N+1 nodes
            g = nx.star_graph(num_v - 1)
            self.graphs.append(g)
            self.labels.append(1)

    def _gen_wheel(self, n):
        for _ in range(n):
            num_v = np.random.randint(self.min_num_v, self.max_num_v)
            g = nx.wheel_graph(num_v)
            self.graphs.append(g)
            self.labels.append(2)

    def _gen_lollipop(self, n):
        for _ in range(n):
            num_v = np.random.randint(self.min_num_v, self.max_num_v)
            path_len = np.random.randint(2, num_v // 2)
            g = nx.lollipop_graph(m=num_v - path_len, n=path_len)
            self.graphs.append(g)
            self.labels.append(3)

# %% [markdown]
# Setup and training
# ------------------
# Create a synthetic dataset of $400$ graphs with $10$ ~
# $20$ nodes. $320$ graphs constitute a training set and
# $80$ graphs constitute a test set.

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

# Create training and test sets.
# trainset = MiniGCDataset(320, 10, 20)
trainset = MiniGCDataset_4c(20, 10, 60)
testset = MiniGCDataset_4c(200, 10, 60)
print(trainset)
# Out:
# <__main__.MiniGCDataset_4c object at 0x7f096fcc5d30>

# %%
# trainset.labels

# %%
# Use PyTorch's DataLoader and the collate function
# defined before.
data_loader = DataLoader(trainset, batch_size=1, shuffle=True,
                         collate_fn=collate)

# Create model
model = Classifier(1, 256, trainset.num_classes)
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
model.train()

epoch_losses = []
for epoch in range(500):
    epoch_loss = 0
    for iter, (bg, label) in enumerate(data_loader):
        prediction = model(bg)
#         print(label)
#         print(prediction)
        loss = loss_func(prediction, label)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
    epoch_loss /= (iter + 1)
    print('Epoch {}, loss {:.4f}'.format(epoch, epoch_loss))
    epoch_losses.append(epoch_loss)
# Out:
# Epoch 0, loss 2.5309
# Epoch 1, loss 2.1095
# Epoch 2, loss 1.7117
# Epoch 3, loss 1.3835
# Epoch 4, loss 1.2864
# Epoch 5, loss 1.1478
# Epoch 6, loss 1.6118
# Epoch 7, loss 1.1537
# Epoch 8, loss 0.9886
# Epoch 9, loss 1.1639
# Epoch 10, loss 1.0736
# Epoch 11, loss 0.8652
# Epoch 12, loss 0.9355
# Epoch 13, loss 0.7946
# Epoch 14, loss 0.8212
# Epoch 15, loss 1.3552
# Epoch 16, loss 0.9837
# Epoch 17, loss 0.8373
# Epoch 18, loss 0.8038
# Epoch 19, loss 0.8252
# Epoch 20, loss 0.7446
# Epoch 21, loss 0.7445
# Epoch 22, loss 0.7418
# Epoch 23, loss 0.6755
# Epoch 24, loss 0.7184
# Epoch 25, loss 0.7414
# Epoch 26, loss 0.7964
# Epoch 27, loss 0.7018
# Epoch 28, loss 0.6969
# Epoch 29, loss 0.7459
# Epoch 30, loss 0.6600
# Epoch 31, loss 0.6786
# Epoch 32, loss 0.6048
# Epoch 33, loss 0.6711
# Epoch 34, loss 0.6462
# Epoch 35, loss 0.6266
# Epoch 36, loss 0.6112
# Epoch 37, loss 0.8217
# Epoch 38, loss 0.6746
# Epoch 39, loss 0.7020
# Epoch 40, loss 1.0114
# Epoch 41, loss 1.1412
# Epoch 42, loss 0.7760
# Epoch 43, loss 0.6734
# Epoch 44, loss 0.6986
# Epoch 45, loss 0.6587
# Epoch 46, loss 0.6585
# Epoch 47, loss 0.6894
# Epoch 48, loss 0.6979
# Epoch 49, loss 0.6703
# Epoch 50, loss 0.6172
# Epoch 51, loss 0.6816
# Epoch 52, loss 0.5859
# Epoch 53, loss 0.6027
# Epoch 54, loss 0.5887
# Epoch 55, loss 0.5846
# Epoch 56, loss 0.5784
# Epoch 57, loss 0.5925
# Epoch 58, loss 0.5877
# Epoch 59, loss 0.6990
# Epoch 60, loss 0.6674
# Epoch 61, loss 0.5783
# Epoch 62, loss 0.5539
# Epoch 63, loss 0.5678
# Epoch 64, loss 0.5604
# Epoch 65, loss 0.5176
# Epoch 66, loss 0.5025
# Epoch 67, loss 0.5174
# Epoch 68, loss 0.5228
# Epoch 69, loss 0.5146
# Epoch 70, loss 0.5444
# Epoch 71, loss 0.4795
# Epoch 72, loss 0.5074
# Epoch 73, loss 0.5108
# Epoch 74, loss 0.4601
# Epoch 75, loss 0.4662
# Epoch 76, loss 0.4889
# Epoch 77, loss 0.4983
# Epoch 78, loss 0.4784
# Epoch 79, loss 0.4718
# Epoch 80, loss 0.4390
# Epoch 81, loss 0.4400
# Epoch 82, loss 0.4867
# Epoch 83, loss 0.4233
# Epoch 84, loss 0.4366
# Epoch 85, loss 0.4599
# Epoch 86, loss 0.4983
# Epoch 87, loss 0.4424
# Epoch 88, loss 0.4263
# Epoch 89, loss 0.5051
# Epoch 90, loss 0.4650
# Epoch 91, loss 0.4223
# Epoch 92, loss 0.4043
# Epoch 93, loss 0.4029
# Epoch 94, loss 0.3698
# Epoch 95, loss 0.4060
# Epoch 96, loss 0.4269
# Epoch 97, loss 0.3794
# Epoch 98, loss 0.3672
# Epoch 99, loss 0.3688
# Epoch 100, loss 0.3771
# Epoch 101, loss 0.4182
# Epoch 102, loss 0.3600
# Epoch 103, loss 0.3383
# Epoch 104, loss 0.3405
# Epoch 105, loss 0.3370
# Epoch 106, loss 0.4028
# Epoch 107, loss 0.3356
# Epoch 108, loss 0.3857
# Epoch 109, loss 0.3499
# Epoch 110, loss 0.3713
# Epoch 111, loss 0.4097
# Epoch 112, loss 0.4496
# Epoch 113, loss 0.3716
# Epoch 114, loss 0.3616
# Epoch 115, loss 0.5188
# Epoch 116, loss 0.3712
# Epoch 117, loss 0.4223
# Epoch 118, loss 0.3327
# Epoch 119, loss 0.3692
# Epoch 120, loss 0.3624
# Epoch 121, loss 0.2939
# Epoch 122, loss 0.2891
# Epoch 123, loss 0.3087
# Epoch 124, loss 0.3090
# Epoch 125, loss 0.2880
# Epoch 126, loss 0.3099
# Epoch 127, loss 0.3796
# Epoch 128, loss 0.4926
# Epoch 129, loss 0.3219
# Epoch 130, loss 0.3096
# Epoch 131, loss 0.2862
# Epoch 132, loss 0.3835
# Epoch 133, loss 0.2720
# Epoch 134, loss 0.2708
# Epoch 135, loss 0.2815
# Epoch 136, loss 0.2677
# Epoch 137, loss 0.2797
# Epoch 138, loss 0.3049
# Epoch 139, loss 0.2770
# Epoch 140, loss 0.3067
# Epoch 141, loss 0.2886
# Epoch 142, loss 0.3258
# Epoch 143, loss 0.2765
# Epoch 144, loss 0.2727
# Epoch 145, loss 0.3175
# Epoch 146, loss 0.2865
# Epoch 147, loss 0.2437
# Epoch 148, loss 0.2466
# Epoch 149, loss 0.2901
# Epoch 150, loss 0.2526
# Epoch 151, loss 0.2820
# Epoch 152, loss 0.3358
# Epoch 153, loss 0.3009
# Epoch 154, loss 0.3677
# Epoch 155, loss 0.2764
# Epoch 156, loss 0.2319
# Epoch 157, loss 0.2297
# Epoch 158, loss 0.2171
# Epoch 159, loss 0.2195
# Epoch 160, loss 0.2256
# Epoch 161, loss 0.2652
# Epoch 162, loss 0.2764
# Epoch 163, loss 0.2312
# Epoch 164, loss 0.2534
# Epoch 165, loss 0.2703
# Epoch 166, loss 0.3506
# Epoch 167, loss 0.2883
# Epoch 168, loss 0.2326
# Epoch 169, loss 0.2917
# Epoch 170, loss 0.2989
# Epoch 171, loss 0.2366
# Epoch 172, loss 0.2266
# Epoch 173, loss 0.2053
# Epoch 174, loss 0.2030
# Epoch 175, loss 0.2012
# Epoch 176, loss 0.2212
# Epoch 177, loss 0.2231
# Epoch 178, loss 0.3262
# Epoch 179, loss 0.3716
# Epoch 180, loss 0.2586
# Epoch 181, loss 0.2394
# Epoch 182, loss 0.2781
# Epoch 183, loss 0.1897
# Epoch 184, loss 0.2157
# Epoch 185, loss 0.2110
# Epoch 186, loss 0.1897
# Epoch 187, loss 0.2644
# Epoch 188, loss 0.1756
# Epoch 189, loss 0.1990
# Epoch 190, loss 0.2151
# Epoch 191, loss 0.2735
# Epoch 192, loss 0.2676
# Epoch 193, loss 0.2206
# Epoch 194, loss 0.2497
# Epoch 195, loss 0.2326
# Epoch 196, loss 0.2210
# Epoch 197, loss 0.2213
# Epoch 198, loss 0.2165
# Epoch 199, loss 0.1840
# Epoch 200, loss 0.2065
# Epoch 201, loss 0.1652
# Epoch 202, loss 0.2003
# Epoch 203, loss 0.2369
# Epoch 204, loss 0.2132
# Epoch 205, loss 0.2401
# Epoch 206, loss 0.1847
# Epoch 207, loss 0.1854
# Epoch 208, loss 0.2559
# Epoch 209, loss 0.2070
# Epoch 210, loss 0.2045
# Epoch 211, loss 0.1810
# Epoch 212, loss 0.1779
# Epoch 213, loss 0.1928
# Epoch 214, loss 0.2091
# Epoch 215, loss 0.1680
# Epoch 216, loss 0.1700
# Epoch 217, loss 0.1874
# Epoch 218, loss 0.1690
# Epoch 219, loss 0.2037
# Epoch 220, loss 0.1931
# Epoch 221, loss 0.1642
# Epoch 222, loss 0.1738
# Epoch 223, loss 0.2730
# Epoch 224, loss 0.2797
# Epoch 225, loss 0.2082
# Epoch 226, loss 0.2388
# Epoch 227, loss 0.1881
# Epoch 228, loss 0.1863
# Epoch 229, loss 0.1709
# Epoch 230, loss 0.1835
# Epoch 231, loss 0.1783
# Epoch 232, loss 0.2487
# Epoch 233, loss 0.1598
# Epoch 234, loss 0.2093
# Epoch 235, loss 0.2209
# Epoch 236, loss 0.2114
# Epoch 237, loss 0.1825
# Epoch 238, loss 0.2008
# Epoch 239, loss 0.1362
# Epoch 240, loss 0.2074
# Epoch 241, loss 0.1896
# Epoch 242, loss 0.1791
# Epoch 243, loss 0.1801
# Epoch 244, loss 0.1721
# Epoch 245, loss 0.2094
# Epoch 246, loss 0.2209
# Epoch 247, loss 0.2088
# Epoch 248, loss 0.2221
# Epoch 249, loss 0.4774
# Epoch 250, loss 0.2236
# Epoch 251, loss 0.3146
# Epoch 252, loss 0.1727
# Epoch 253, loss 0.2087
# Epoch 254, loss 0.1864
# Epoch 255, loss 0.1724
# Epoch 256, loss 0.1771
# Epoch 257, loss 0.1523
# Epoch 258, loss 0.1549
# Epoch 259, loss 0.2143
# Epoch 260, loss 0.2484
# Epoch 261, loss 0.1646
# Epoch 262, loss 0.1423
# Epoch 263, loss 0.1496
# Epoch 264, loss 0.1552
# Epoch 265, loss 0.1473
# Epoch 266, loss 0.1616
# Epoch 267, loss 0.1921
# Epoch 268, loss 0.1459
# Epoch 269, loss 0.1613
# Epoch 270, loss 0.1293
# Epoch 271, loss 0.1598
# Epoch 272, loss 0.2060
# Epoch 273, loss 0.2082
# Epoch 274, loss 0.1649
# Epoch 275, loss 0.1955
# Epoch 276, loss 0.1263
# Epoch 277, loss 0.1583
# Epoch 278, loss 0.1693
# Epoch 279, loss 0.1753
# Epoch 280, loss 0.1531
# Epoch 281, loss 0.1994
# Epoch 282, loss 0.2713
# Epoch 283, loss 0.1659
# Epoch 284, loss 0.1446
# Epoch 285, loss 0.1391
# Epoch 286, loss 0.1762
# Epoch 287, loss 0.1125
# Epoch 288, loss 0.2410
# Epoch 289, loss 0.2251
# Epoch 290, loss 0.2463
# Epoch 291, loss 0.3005
# Epoch 292, loss 0.1532
# Epoch 293, loss 0.1965
# Epoch 294, loss 0.1529
# Epoch 295, loss 0.1425
# Epoch 296, loss 0.1723
# Epoch 297, loss 0.1303
# Epoch 298, loss 0.1762
# Epoch 299, loss 0.1461
# Epoch 300, loss 0.1606
# Epoch 301, loss 0.1489
# Epoch 302, loss 0.1503
# Epoch 303, loss 0.1427
# Epoch 304, loss 0.1515
# Epoch 305, loss 0.1380
# Epoch 306, loss 0.1470
# Epoch 307, loss 0.1462
# Epoch 308, loss 0.2015
# Epoch 309, loss 0.1387
# Epoch 310, loss 0.2230
# Epoch 311, loss 0.1701
# Epoch 312, loss 0.1218
# Epoch 313, loss 0.1669
# Epoch 314, loss 0.1623
# Epoch 315, loss 0.2006
# Epoch 316, loss 0.1545
# Epoch 317, loss 0.2014
# Epoch 318, loss 0.2415
# Epoch 319, loss 0.2476
# Epoch 320, loss 0.1275
# Epoch 321, loss 0.1740
# Epoch 322, loss 0.1437
# Epoch 323, loss 0.1392
# Epoch 324, loss 0.1411
# Epoch 325, loss 0.1793
# Epoch 326, loss 0.1670
# Epoch 327, loss 0.1634
# Epoch 328, loss 0.1792
# Epoch 329, loss 0.1384
# Epoch 330, loss 0.1674
# Epoch 331, loss 0.1412
# Epoch 332, loss 0.1560
# Epoch 333, loss 0.1422
# Epoch 334, loss 0.1620
# Epoch 335, loss 0.1379
# Epoch 336, loss 0.1501
# Epoch 337, loss 0.1304
# Epoch 338, loss 0.1378
# Epoch 339, loss 0.1215
# Epoch 340, loss 0.1317
# Epoch 341, loss 0.1226
# Epoch 342, loss 0.1855
# Epoch 343, loss 0.2685
# Epoch 344, loss 0.2530
# Epoch 345, loss 0.1510
# Epoch 346, loss 0.1427
# Epoch 347, loss 0.1768
# Epoch 348, loss 0.1447
# Epoch 349, loss 0.1317
# Epoch 350, loss 0.1556
# Epoch 351, loss 0.1326
# Epoch 352, loss 0.1418
# Epoch 353, loss 0.1263
# Epoch 354, loss 0.1099
# Epoch 355, loss 0.1216
# Epoch 356, loss 0.1193
# Epoch 357, loss 0.1266
# Epoch 358, loss 0.1467
# Epoch 359, loss 0.1092
# Epoch 360, loss 0.1699
# Epoch 361, loss 0.1098
# Epoch 362, loss 0.1650
# Epoch 363, loss 0.1270
# Epoch 364, loss 0.1230
# Epoch 365, loss 0.1599
# Epoch 366, loss 0.1353
# Epoch 367, loss 0.1461
# Epoch 368, loss 0.1270
# Epoch 369, loss 0.1258
# Epoch 370, loss 0.1039
# Epoch 371, loss 0.1590
# Epoch 372, loss 0.1435
# Epoch 373, loss 0.1221
# Epoch 374, loss 0.1003
# Epoch 375, loss 0.1595
# Epoch 376, loss 0.1106
# Epoch 377, loss 0.1216
# Epoch 378, loss 0.1993
# Epoch 379, loss 0.1517
# Epoch 380, loss 0.2098
# Epoch 381, loss 0.2026
# Epoch 382, loss 0.1314
# Epoch 383, loss 0.0971
# Epoch 384, loss 0.1182
# Epoch 385, loss 0.1628
# Epoch 386, loss 0.1560
# Epoch 387, loss 0.1102
# Epoch 388, loss 0.1296
# Epoch 389, loss 0.1343
# Epoch 390, loss 0.1115
# Epoch 391, loss 0.1312
# Epoch 392, loss 0.1007
# Epoch 393, loss 0.1216
# Epoch 394, loss 0.1360
# Epoch 395, loss 0.1547
# Epoch 396, loss 0.1304
# Epoch 397, loss 0.1386
# Epoch 398, loss 0.1227
# Epoch 399, loss 0.1106
# Epoch 400, loss 0.1133
# Epoch 401, loss 0.1159
# Epoch 402, loss 0.1130
# Epoch 403, loss 0.1146
# Epoch 404, loss 0.1054
# Epoch 405, loss 0.1460
# Epoch 406, loss 0.1265
# Epoch 407, loss 0.1233
# Epoch 408, loss 0.1613
# Epoch 409, loss 0.1410
# Epoch 410, loss 0.1041
# Epoch 411, loss 0.3394
# Epoch 412, loss 0.1639
# Epoch 413, loss 0.1293
# Epoch 414, loss 0.1475
# Epoch 415, loss 0.0923
# Epoch 416, loss 0.1292
# Epoch 417, loss 0.1926
# Epoch 418, loss 0.2031
# Epoch 419, loss 0.0990
# Epoch 420, loss 0.1066
# Epoch 421, loss 0.1194
# Epoch 422, loss 0.5061
# Epoch 423, loss 0.6057
# Epoch 424, loss 0.4605
# Epoch 425, loss 0.4278
# Epoch 426, loss 0.3522
# Epoch 427, loss 0.3336
# Epoch 428, loss 0.3138
# Epoch 429, loss 0.2838
# Epoch 430, loss 0.2919
# Epoch 431, loss 0.2699
# Epoch 432, loss 0.2977
# Epoch 433, loss 0.2859
# Epoch 434, loss 0.2482
# Epoch 435, loss 0.2365
# Epoch 436, loss 0.2333
# Epoch 437, loss 0.2627
# Epoch 438, loss 0.2954
# Epoch 439, loss 0.2342
# Epoch 440, loss 0.2906
# Epoch 441, loss 0.2127
# Epoch 442, loss 0.2092
# Epoch 443, loss 0.2333
# Epoch 444, loss 0.2688
# Epoch 445, loss 0.2563
# Epoch 446, loss 0.2624
# Epoch 447, loss 0.1942
# Epoch 448, loss 0.1917
# Epoch 449, loss 0.1792
# Epoch 450, loss 0.1875
# Epoch 451, loss 0.1904
# Epoch 452, loss 0.1739
# Epoch 453, loss 0.1685
# Epoch 454, loss 0.2426
# Epoch 455, loss 0.1965
# Epoch 456, loss 0.1746
# Epoch 457, loss 0.1717
# Epoch 458, loss 0.1720
# Epoch 459, loss 0.1883
# Epoch 460, loss 0.2988
# Epoch 461, loss 0.1880
# Epoch 462, loss 0.1558
# Epoch 463, loss 0.1971
# Epoch 464, loss 0.1801
# Epoch 465, loss 0.1588
# Epoch 466, loss 0.1614
# Epoch 467, loss 0.1606
# Epoch 468, loss 0.1634
# Epoch 469, loss 0.1523
# Epoch 470, loss 0.1720
# Epoch 471, loss 0.1607
# Epoch 472, loss 0.1549
# Epoch 473, loss 0.1853
# Epoch 474, loss 0.1645
# Epoch 475, loss 0.2027
# Epoch 476, loss 0.2185
# Epoch 477, loss 0.1684
# Epoch 478, loss 0.1433
# Epoch 479, loss 0.2009
# Epoch 480, loss 0.1849
# Epoch 481, loss 0.1669
# Epoch 482, loss 0.1425
# Epoch 483, loss 0.1374
# Epoch 484, loss 0.1392
# Epoch 485, loss 0.1318
# Epoch 486, loss 0.1321
# Epoch 487, loss 0.1277
# Epoch 488, loss 0.1805
# Epoch 489, loss 0.1426
# Epoch 490, loss 0.1142
# Epoch 491, loss 0.1362
# Epoch 492, loss 0.1350
# Epoch 493, loss 0.1321
# Epoch 494, loss 0.1325
# Epoch 495, loss 0.1688
# Epoch 496, loss 0.1205
# Epoch 497, loss 0.1241
# Epoch 498, loss 0.1338
# Epoch 499, loss 0.1498

# %% [markdown]
# The learning curve of a run is presented below.

# %%
import matplotlib.pyplot as plt

# %%
plt.title('cross entropy averaged over minibatches')
plt.plot(epoch_losses)
plt.show()

# %% [markdown]
# The trained model is evaluated on the test set created. To deploy
# the tutorial, restrict the running time to get a higher
# accuracy ($80$ % ~ $90$ %) than the ones printed below.

# %%
model.eval()
# Convert a list of tuples to two lists
test_X, test_Y = map(list, zip(*testset))

# print(test_X)
# print(test_Y)
test_bg = dgl.batch(test_X)
test_Y = torch.tensor(test_Y).float().view(-1, 1)
probs_Y = torch.softmax(model(test_bg), 1)
sampled_Y = torch.multinomial(probs_Y, 1)
argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)
print('Accuracy of sampled predictions on the test set: {:.4f}%'.format(
    (test_Y == sampled_Y.float()).sum().item() / len(test_Y) * 100))
print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
    (test_Y == argmax_Y.float()).sum().item() / len(test_Y) * 100))
# Out:
# Accuracy of sampled predictions on the test set: 81.5000%
# Accuracy of argmax predictions on the test set: 79.000000%

# %% [markdown]
# ## Finish Training and Testing

# %% [markdown]
# ## End
