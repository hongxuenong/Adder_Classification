# %%
# %matplotlib inline

# %% [markdown]
# ## Setup GPU Device

# %%
import random

# %%
import os
#Set GPU IDs for training:
os.environ["CUDA_VISIBLE_DEVICES"] = '3'

# %%
import dgl
def build_circuit_graph_undirected(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(src, dst)
    g.add_edges(dst, src)
    return g

def build_circuit_graph_directed_sd(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(src, dst)
    return g

def build_circuit_graph_directed_ds(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(dst, src)
    return g

# %% [markdown]
# ### Choose Number of Training Samples

# %% [markdown]
# ### Train Test Split

# %%
import random
random.seed(0)
training_size = 30
training_idx = random.sample(list(range(4,65)), training_size)
test_idx = [item for item in list(range(4,65)) if item not in training_idx]

# %% [markdown]
# ## Pick Training Data

# %%
import os
import matplotlib.pyplot as plt
import networkx as nx
import csv
import numpy as np
dir = 'training_data'

trainset=[]
labels=[]
#for filename in os.listdir(dir):
np.random.seed(0)
sample_size = 5
# training_idx = np.random.randint(4,64,10)
training_idx_1 = np.random.choice(training_idx, size=sample_size, replace=False)
training_idx_2 = np.random.choice(training_idx, size=sample_size, replace=False)
training_idx_3 = np.random.choice(training_idx, size=sample_size, replace=False)
training_idx_4 = np.random.choice(training_idx, size=sample_size, replace=False)

# training_idx_2 = training_idx_1
# training_idx_3 = training_idx_1
# training_idx_4 = training_idx_1
# training_idx_1 = [6]
# training_idx_2 = [6]
# training_idx_3 = [6]
# training_idx_4 = [6]
print(training_idx_1,training_idx_2,training_idx_3,training_idx_4)
# Out:
# [52 25 26 54 44] [ 6 57 10 20 26] [13  8 43 53 41] [53 20 54 64 12]

# %% [markdown]
# ### Prepare Training and Test Data

# %%
for idx in range(len(training_idx_1)):
    node_list=[]
    edge_list=[]
    label_list=[]
    node_list2=[]
    edge_list2=[]
    label_list2=[]
    node_list3=[]
    edge_list3=[]
    label_list3=[]
    node_list4=[]
    edge_list4=[]
    label_list4=[]
    for j in ["node_list","edge_list","graph_label"]:
        filename = "rca_"+str(training_idx_1[idx])+"bit"+j+'.csv'
        filename2 = "cla_"+str(training_idx_2[idx])+"bit"+j+'.csv'
        filename3 = "csa_"+str(training_idx_3[idx])+"bit"+j+'.csv'
        filename4 = "CSkipA_"+str(training_idx_4[idx])+"bit"+j+'.csv'
        if(filename.find("node_list")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                node_list = list(reader)
                
        if(filename.find("edge_list")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list = list(reader)
        if(filename.find("graph_label")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                label_list = list(reader)
        if(filename.find("gate_type")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type = list(reader)
        
        if(filename2.find("node_list")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                node_list2 = list(reader)
                
        if(filename2.find("edge_list")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list2 = list(reader)
        if(filename2.find("graph_label")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                label_list2 = list(reader)
        if(filename2.find("gate_type")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type2 = list(reader)
        
        if(filename3.find("node_list")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                node_list3 = list(reader)
                
        if(filename3.find("edge_list")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list3 = list(reader)
        if(filename3.find("graph_label")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                label_list3 = list(reader)
        if(filename3.find("gate_type")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type3 = list(reader)
        if(filename4.find("node_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                node_list4 = list(reader)
                
        if(filename4.find("edge_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list4 = list(reader)
        if(filename4.find("graph_label")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                label_list4 = list(reader)
        if(filename4.find("gate_type")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type4 = list(reader)
    #create dgl graph
    g=build_circuit_graph_undirected(node_list,edge_list)
    trainset.append(g)
    labels.append(label_list[0])
    g2=build_circuit_graph_undirected(node_list2,edge_list2)
    trainset.append(g2)
    labels.append(label_list2[0])
    g3=build_circuit_graph_undirected(node_list3,edge_list3)
    trainset.append(g3)
    labels.append(label_list3[0])
    g4=build_circuit_graph_undirected(node_list4,edge_list4)
    trainset.append(g4)
    labels.append(label_list4[0])

for i in labels:
    i[0] = int(i[0])

print(labels)
# Out:
# [[1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3]]

# %% [markdown]
# ### Visualize Training Data

# %%
# graph = trainset[14]
# label=labels[14][0]

# fig, ax = plt.subplots()
# G=graph.to_networkx()
# pos=nx.spring_layout(G)
# nx.draw(G,pos)
# nx.draw_networkx_labels(G,pos, ax=ax)
# ax.set_title('Class: {:f}'.format(label))
# plt.show()

# %% [markdown]
# ### Apply random shuffle to training set

# %%
##apply random shuffle on the trainset
np.random.seed(0)
randomize = np.arange(len(trainset))
np.random.shuffle(randomize)
labels_shuffled=[]
trainset_shuffled=[]
for i in range (len(randomize)):
    labels_shuffled.append(labels[randomize[i]])
    trainset_shuffled.append(trainset[randomize[i]])

# %%
len(trainset_shuffled)
# Out:
# 20

# %%
import dgl

def collate(samples):
    # The input `samples` is a list of pairs
    #  (graph, label).
    graphs, labels = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs)
    return batched_graph, torch.tensor(labels)

# %%
import dgl.function as fn
import torch
import torch.nn as nn

# Sends a message of node feature h.
msg = fn.copy_src(src='h', out='m')

def reduce(nodes):
    """Take an average over all neighbor node features hu and use it to
    overwrite the original node feature."""
    accum = torch.mean(nodes.mailbox['m'], 1)
    return {'h': accum}

class NodeApplyModule(nn.Module):
    """Update the node feature hv with ReLU(Whv+b)."""
    def __init__(self, in_feats, out_feats, activation):
        super(NodeApplyModule, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        self.activation = activation

    def forward(self, node):
        h = self.linear(node.data['h'])
        h = self.activation(h)
        return {'h' : h}

class GCN(nn.Module):
    def __init__(self, in_feats, out_feats, activation):
        super(GCN, self).__init__()
        self.apply_mod = NodeApplyModule(in_feats, out_feats, activation)

    def forward(self, g, feature):
        # Initialize the node features with h.
        g.ndata['h'] = feature
        g.update_all(msg, reduce)
        g.apply_nodes(func=self.apply_mod)
        return g.ndata.pop('h')

# %% [markdown]
# ### Readout and classification

# %%
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()

        self.layers = nn.ModuleList([
            GCN(in_dim, hidden_dim, F.relu),
            GCN(hidden_dim, hidden_dim, F.relu)])
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g):
        # For undirected graphs, in_degree is the same as
        # out_degree.
        h = g.in_degrees().view(-1, 1).float().cuda()
        for conv in self.layers:
            h = conv(g, h)
        g.ndata['h'] = h
        hg = dgl.mean_nodes(g, 'h')
        return self.classify(hg)

# %% [markdown]
# ### Setup and training

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

# %% [markdown]
# ### Make Training Deterministic

# %%
# import torch
# torch.manual_seed(0)
# #CuDNN:
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Set Training Epoch

# %%
training_epoch = 500 #original = 1500 for 1 training sample 500 for 20 sample
initial_lr = 0.001

# %%
# Create model
#model = Classifier(1, 256, trainset.num_classes)
model = Classifier(1, 256, 4)
model.cuda()
loss_func = nn.CrossEntropyLoss().cuda()
optimizer = optim.Adam(model.parameters(), lr = initial_lr)
# optimizer = optim.AdamW(model.parameters(), lr = initial_lr)
model.train()

labels_shuffled = torch.LongTensor(labels_shuffled).cuda()

epoch_losses = []

for epoch in range(training_epoch):
    model.train()
    epoch_loss = 0
    for iter, bg in enumerate(trainset_shuffled):
        prediction=torch.zeros(1,4,dtype=torch.float64).cuda()
        prediction[0] = model(bg)

        loss = loss_func(prediction, labels_shuffled[iter])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
    epoch_loss /= (iter + 1)
    print('Epoch {}, loss {:.4f}'.format(epoch, epoch_loss))
    epoch_losses.append(epoch_loss)
    
#     if (epoch%5==0):
#         model.eval()
#         eval_bg = dgl.batch(trainset_shuffled)
#         eval_labels = torch.tensor(labels_shuffled).float().view(-1, 1)
#         probs_Y = torch.softmax(model(eval_bg), 1)
#         argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)

#         print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
#             (eval_labels == argmax_Y.float()).sum().item() / len(eval_labels) * 100))
# Out:
# Epoch 0, loss 1.5971
# Epoch 1, loss 1.6108
# Epoch 2, loss 1.4693
# Epoch 3, loss 1.4512
# Epoch 4, loss 1.4466
# Epoch 5, loss 1.4287
# Epoch 6, loss 1.4153
# Epoch 7, loss 1.4027
# Epoch 8, loss 1.3883
# Epoch 9, loss 1.3751
# Epoch 10, loss 1.3621
# Epoch 11, loss 1.3492
# Epoch 12, loss 1.3358
# Epoch 13, loss 1.3209
# Epoch 14, loss 1.3052
# Epoch 15, loss 1.2893
# Epoch 16, loss 1.2729
# Epoch 17, loss 1.2555
# Epoch 18, loss 1.2386
# Epoch 19, loss 1.2212
# Epoch 20, loss 1.2039
# Epoch 21, loss 1.2044
# Epoch 22, loss 1.1692
# Epoch 23, loss 1.1565
# Epoch 24, loss 1.1405
# Epoch 25, loss 1.1258
# Epoch 26, loss 1.1132
# Epoch 27, loss 1.1007
# Epoch 28, loss 1.0897
# Epoch 29, loss 1.0791
# Epoch 30, loss 1.0697
# Epoch 31, loss 1.0613
# Epoch 32, loss 1.0546
# Epoch 33, loss 1.0472
# Epoch 34, loss 1.0409
# Epoch 35, loss 1.0351
# Epoch 36, loss 1.0286
# Epoch 37, loss 1.0214
# Epoch 38, loss 1.0162
# Epoch 39, loss 1.0046
# Epoch 40, loss 0.9938
# Epoch 41, loss 0.9831
# Epoch 42, loss 0.9730
# Epoch 43, loss 1.0351
# Epoch 44, loss 0.9912
# Epoch 45, loss 0.9508
# Epoch 46, loss 0.9355
# Epoch 47, loss 0.9216
# Epoch 48, loss 0.9132
# Epoch 49, loss 0.9061
# Epoch 50, loss 0.8992
# Epoch 51, loss 0.8923
# Epoch 52, loss 0.8889
# Epoch 53, loss 0.9171
# Epoch 54, loss 0.8801
# Epoch 55, loss 0.8715
# Epoch 56, loss 0.8610
# Epoch 57, loss 0.8540
# Epoch 58, loss 0.8946
# Epoch 59, loss 0.8727
# Epoch 60, loss 0.8503
# Epoch 61, loss 0.8333
# Epoch 62, loss 0.8268
# Epoch 63, loss 0.8211
# Epoch 64, loss 0.8782
# Epoch 65, loss 0.8371
# Epoch 66, loss 0.8176
# Epoch 67, loss 0.8013
# Epoch 68, loss 0.7952
# Epoch 69, loss 0.7897
# Epoch 70, loss 0.7850
# Epoch 71, loss 0.7799
# Epoch 72, loss 0.7752
# Epoch 73, loss 0.7697
# Epoch 74, loss 0.7643
# Epoch 75, loss 0.7595
# Epoch 76, loss 0.7542
# Epoch 77, loss 0.7487
# Epoch 78, loss 0.7440
# Epoch 79, loss 0.7379
# Epoch 80, loss 0.7335
# Epoch 81, loss 0.7279
# Epoch 82, loss 0.7224
# Epoch 83, loss 0.7169
# Epoch 84, loss 0.7127
# Epoch 85, loss 0.7070
# Epoch 86, loss 0.7040
# Epoch 87, loss 0.6968
# Epoch 88, loss 0.6905
# Epoch 89, loss 0.6867
# Epoch 90, loss 0.6809
# Epoch 91, loss 0.6761
# Epoch 92, loss 0.6712
# Epoch 93, loss 0.6702
# Epoch 94, loss 0.6621
# Epoch 95, loss 0.6555
# Epoch 96, loss 0.6506
# Epoch 97, loss 0.6457
# Epoch 98, loss 0.6406
# Epoch 99, loss 0.6359
# Epoch 100, loss 0.6318
# Epoch 101, loss 0.6262
# Epoch 102, loss 0.6222
# Epoch 103, loss 0.6175
# Epoch 104, loss 0.6133
# Epoch 105, loss 0.6085
# Epoch 106, loss 0.6041
# Epoch 107, loss 0.6005
# Epoch 108, loss 0.5960
# Epoch 109, loss 0.5918
# Epoch 110, loss 0.5884
# Epoch 111, loss 0.5839
# Epoch 112, loss 0.5799
# Epoch 113, loss 0.5769
# Epoch 114, loss 0.6088
# Epoch 115, loss 0.6186
# Epoch 116, loss 0.5615
# Epoch 117, loss 0.5626
# Epoch 118, loss 0.5571
# Epoch 119, loss 0.5577
# Epoch 120, loss 0.5546
# Epoch 121, loss 0.5486
# Epoch 122, loss 0.5470
# Epoch 123, loss 0.5439
# Epoch 124, loss 0.5410
# Epoch 125, loss 0.5389
# Epoch 126, loss 0.5363
# Epoch 127, loss 0.5342
# Epoch 128, loss 0.5314
# Epoch 129, loss 0.5304
# Epoch 130, loss 0.5277
# Epoch 131, loss 0.5829
# Epoch 132, loss 0.7274
# Epoch 133, loss 0.5022
# Epoch 134, loss 0.5170
# Epoch 135, loss 0.5240
# Epoch 136, loss 0.5191
# Epoch 137, loss 0.5213
# Epoch 138, loss 0.5206
# Epoch 139, loss 0.5202
# Epoch 140, loss 0.5215
# Epoch 141, loss 0.5210
# Epoch 142, loss 0.5235
# Epoch 143, loss 0.5237
# Epoch 144, loss 0.5269
# Epoch 145, loss 0.5288
# Epoch 146, loss 0.5311
# Epoch 147, loss 0.5320
# Epoch 148, loss 0.5347
# Epoch 149, loss 0.5367
# Epoch 150, loss 0.5367
# Epoch 151, loss 0.5381
# Epoch 152, loss 0.5356
# Epoch 153, loss 0.5559
# Epoch 154, loss 0.5518
# Epoch 155, loss 0.5158
# Epoch 156, loss 0.5143
# Epoch 157, loss 0.5054
# Epoch 158, loss 0.4981
# Epoch 159, loss 0.4899
# Epoch 160, loss 0.4826
# Epoch 161, loss 0.4758
# Epoch 162, loss 0.4697
# Epoch 163, loss 0.4639
# Epoch 164, loss 0.4592
# Epoch 165, loss 0.4542
# Epoch 166, loss 0.4516
# Epoch 167, loss 0.4472
# Epoch 168, loss 0.4424
# Epoch 169, loss 0.4393
# Epoch 170, loss 0.4365
# Epoch 171, loss 0.4334
# Epoch 172, loss 0.4308
# Epoch 173, loss 0.4284
# Epoch 174, loss 0.4259
# Epoch 175, loss 0.4239
# Epoch 176, loss 0.4219
# Epoch 177, loss 0.4201
# Epoch 178, loss 0.4181
# Epoch 179, loss 0.4163
# Epoch 180, loss 0.4144
# Epoch 181, loss 0.4128
# Epoch 182, loss 0.4108
# Epoch 183, loss 0.4093
# Epoch 184, loss 0.4077
# Epoch 185, loss 0.4063
# Epoch 186, loss 0.4046
# Epoch 187, loss 0.4031
# Epoch 188, loss 0.4016
# Epoch 189, loss 0.4004
# Epoch 190, loss 0.3987
# Epoch 191, loss 0.3977
# Epoch 192, loss 0.3960
# Epoch 193, loss 0.3948
# Epoch 194, loss 0.3936
# Epoch 195, loss 0.3921
# Epoch 196, loss 0.3909
# Epoch 197, loss 0.3895
# Epoch 198, loss 0.4431
# Epoch 199, loss 0.4322
# Epoch 200, loss 0.3744
# Epoch 201, loss 0.3870
# Epoch 202, loss 0.3819
# Epoch 203, loss 0.3824
# Epoch 204, loss 0.3812
# Epoch 205, loss 0.3795
# Epoch 206, loss 0.3794
# Epoch 207, loss 0.3776
# Epoch 208, loss 0.3775
# Epoch 209, loss 0.3760
# Epoch 210, loss 0.3752
# Epoch 211, loss 0.3743
# Epoch 212, loss 0.3735
# Epoch 213, loss 0.3727
# Epoch 214, loss 0.3713
# Epoch 215, loss 0.3710
# Epoch 216, loss 0.3704
# Epoch 217, loss 0.3684
# Epoch 218, loss 0.3684
# Epoch 219, loss 0.3673
# Epoch 220, loss 0.3667
# Epoch 221, loss 0.3648
# Epoch 222, loss 0.3657
# Epoch 223, loss 0.3640
# Epoch 224, loss 0.3629
# Epoch 225, loss 0.3621
# Epoch 226, loss 0.3614
# Epoch 227, loss 0.3612
# Epoch 228, loss 0.3596
# Epoch 229, loss 0.3590
# Epoch 230, loss 0.3583
# Epoch 231, loss 0.3580
# Epoch 232, loss 0.3564
# Epoch 233, loss 0.3562
# Epoch 234, loss 0.3550
# Epoch 235, loss 0.3542
# Epoch 236, loss 0.3534
# Epoch 237, loss 0.3520
# Epoch 238, loss 0.3528
# Epoch 239, loss 0.3509
# Epoch 240, loss 0.3498
# Epoch 241, loss 0.3639
# Epoch 242, loss 0.3439
# Epoch 243, loss 0.3492
# Epoch 244, loss 0.3459
# Epoch 245, loss 0.3462
# Epoch 246, loss 0.3447
# Epoch 247, loss 0.3447
# Epoch 248, loss 0.3427
# Epoch 249, loss 0.3430
# Epoch 250, loss 0.3408
# Epoch 251, loss 0.3404
# Epoch 252, loss 0.3401
# Epoch 253, loss 0.3384
# Epoch 254, loss 0.3371
# Epoch 255, loss 0.3376
# Epoch 256, loss 0.3348
# Epoch 257, loss 0.3345
# Epoch 258, loss 0.3350
# Epoch 259, loss 0.3334
# Epoch 260, loss 0.3312
# Epoch 261, loss 0.3314
# Epoch 262, loss 0.3288
# Epoch 263, loss 0.3294
# Epoch 264, loss 0.3278
# Epoch 265, loss 0.3262
# Epoch 266, loss 0.3254
# Epoch 267, loss 0.3248
# Epoch 268, loss 0.3810
# Epoch 269, loss 0.3715
# Epoch 270, loss 0.3163
# Epoch 271, loss 0.3149
# Epoch 272, loss 0.3193
# Epoch 273, loss 0.3167
# Epoch 274, loss 0.3155
# Epoch 275, loss 0.3151
# Epoch 276, loss 0.3135
# Epoch 277, loss 0.3118
# Epoch 278, loss 0.3124
# Epoch 279, loss 0.3104
# Epoch 280, loss 0.3087
# Epoch 281, loss 0.3075
# Epoch 282, loss 0.3073
# Epoch 283, loss 0.3050
# Epoch 284, loss 0.3046
# Epoch 285, loss 0.3029
# Epoch 286, loss 0.3027
# Epoch 287, loss 0.3010
# Epoch 288, loss 0.2991
# Epoch 289, loss 0.2987
# Epoch 290, loss 0.2971
# Epoch 291, loss 0.2958
# Epoch 292, loss 0.2951
# Epoch 293, loss 0.2929
# Epoch 294, loss 0.2914
# Epoch 295, loss 0.2903
# Epoch 296, loss 0.2893
# Epoch 297, loss 0.2867
# Epoch 298, loss 0.2868
# Epoch 299, loss 0.2847
# Epoch 300, loss 0.2834
# Epoch 301, loss 0.2812
# Epoch 302, loss 0.2809
# Epoch 303, loss 0.2795
# Epoch 304, loss 0.2783
# Epoch 305, loss 0.2758
# Epoch 306, loss 0.2748
# Epoch 307, loss 0.2734
# Epoch 308, loss 0.2731
# Epoch 309, loss 0.2707
# Epoch 310, loss 0.2701
# Epoch 311, loss 0.2671
# Epoch 312, loss 0.2663
# Epoch 313, loss 0.2635
# Epoch 314, loss 0.2902
# Epoch 315, loss 0.2776
# Epoch 316, loss 0.2494
# Epoch 317, loss 0.2573
# Epoch 318, loss 0.2590
# Epoch 319, loss 0.2556
# Epoch 320, loss 0.2529
# Epoch 321, loss 0.2523
# Epoch 322, loss 0.2842
# Epoch 323, loss 0.2365
# Epoch 324, loss 0.2492
# Epoch 325, loss 0.2491
# Epoch 326, loss 0.2449
# Epoch 327, loss 0.2421
# Epoch 328, loss 0.2427
# Epoch 329, loss 0.2408
# Epoch 330, loss 0.2391
# Epoch 331, loss 0.2378
# Epoch 332, loss 0.2361
# Epoch 333, loss 0.2350
# Epoch 334, loss 0.2335
# Epoch 335, loss 0.2311
# Epoch 336, loss 0.2301
# Epoch 337, loss 0.2299
# Epoch 338, loss 0.2269
# Epoch 339, loss 0.2246
# Epoch 340, loss 0.2250
# Epoch 341, loss 0.2225
# Epoch 342, loss 0.2176
# Epoch 343, loss 0.2534
# Epoch 344, loss 0.2535
# Epoch 345, loss 0.2112
# Epoch 346, loss 0.2037
# Epoch 347, loss 0.2116
# Epoch 348, loss 0.2127
# Epoch 349, loss 0.2090
# Epoch 350, loss 0.2068
# Epoch 351, loss 0.2049
# Epoch 352, loss 0.2038
# Epoch 353, loss 0.2032
# Epoch 354, loss 0.2017
# Epoch 355, loss 0.2008
# Epoch 356, loss 0.1991
# Epoch 357, loss 0.1965
# Epoch 358, loss 0.1949
# Epoch 359, loss 0.1947
# Epoch 360, loss 0.1922
# Epoch 361, loss 0.2400
# Epoch 362, loss 0.2402
# Epoch 363, loss 0.2097
# Epoch 364, loss 0.1800
# Epoch 365, loss 0.1740
# Epoch 366, loss 0.1800
# Epoch 367, loss 0.1819
# Epoch 368, loss 0.1784
# Epoch 369, loss 0.1763
# Epoch 370, loss 0.1747
# Epoch 371, loss 0.1742
# Epoch 372, loss 0.1729
# Epoch 373, loss 0.1707
# Epoch 374, loss 0.1687
# Epoch 375, loss 0.1679
# Epoch 376, loss 0.1671
# Epoch 377, loss 0.1653
# Epoch 378, loss 0.1629
# Epoch 379, loss 0.1619
# Epoch 380, loss 0.1610
# Epoch 381, loss 0.1584
# Epoch 382, loss 0.1573
# Epoch 383, loss 0.1567
# Epoch 384, loss 0.1543
# Epoch 385, loss 0.1527
# Epoch 386, loss 0.1516
# Epoch 387, loss 0.1503
# Epoch 388, loss 0.1477
# Epoch 389, loss 0.1466
# Epoch 390, loss 0.1452
# Epoch 391, loss 0.1444
# Epoch 392, loss 0.1426
# Epoch 393, loss 0.1411
# Epoch 394, loss 0.1394
# Epoch 395, loss 0.1379
# Epoch 396, loss 0.1365
# Epoch 397, loss 0.1353
# Epoch 398, loss 0.1337
# Epoch 399, loss 0.1320
# Epoch 400, loss 0.1298
# Epoch 401, loss 0.1285
# Epoch 402, loss 0.1274
# Epoch 403, loss 0.1267
# Epoch 404, loss 0.1250
# Epoch 405, loss 0.1250
# Epoch 406, loss 0.1315
# Epoch 407, loss 0.1294
# Epoch 408, loss 0.1192
# Epoch 409, loss 0.1346
# Epoch 410, loss 0.1537
# Epoch 411, loss 0.1378
# Epoch 412, loss 0.1095
# Epoch 413, loss 0.0948
# Epoch 414, loss 0.0967
# Epoch 415, loss 0.1013
# Epoch 416, loss 0.1034
# Epoch 417, loss 0.1031
# Epoch 418, loss 0.1016
# Epoch 419, loss 0.0993
# Epoch 420, loss 0.0973
# Epoch 421, loss 0.0955
# Epoch 422, loss 0.0938
# Epoch 423, loss 0.0917
# Epoch 424, loss 0.0906
# Epoch 425, loss 0.0893
# Epoch 426, loss 0.0882
# Epoch 427, loss 0.0867
# Epoch 428, loss 0.0853
# Epoch 429, loss 0.0837
# Epoch 430, loss 0.0825
# Epoch 431, loss 0.0812
# Epoch 432, loss 0.0799
# Epoch 433, loss 0.0790
# Epoch 434, loss 0.0778
# Epoch 435, loss 0.0764
# Epoch 436, loss 0.0752
# Epoch 437, loss 0.0739
# Epoch 438, loss 0.0727
# Epoch 439, loss 0.0714
# Epoch 440, loss 0.0702
# Epoch 441, loss 0.0691
# Epoch 442, loss 0.0678
# Epoch 443, loss 0.0667
# Epoch 444, loss 0.0655
# Epoch 445, loss 0.0644
# Epoch 446, loss 0.0632
# Epoch 447, loss 0.0621
# Epoch 448, loss 0.0609
# Epoch 449, loss 0.0599
# Epoch 450, loss 0.0590
# Epoch 451, loss 0.0579
# Epoch 452, loss 0.0570
# Epoch 453, loss 0.0560
# Epoch 454, loss 0.0550
# Epoch 455, loss 0.0541
# Epoch 456, loss 0.0532
# Epoch 457, loss 0.0524
# Epoch 458, loss 0.0515
# Epoch 459, loss 0.0506
# Epoch 460, loss 0.0498
# Epoch 461, loss 0.0490
# Epoch 462, loss 0.0482
# Epoch 463, loss 0.0474
# Epoch 464, loss 0.0466
# Epoch 465, loss 0.0458
# Epoch 466, loss 0.0451
# Epoch 467, loss 0.0443
# Epoch 468, loss 0.0436
# Epoch 469, loss 0.0429
# Epoch 470, loss 0.0422
# Epoch 471, loss 0.0415
# Epoch 472, loss 0.0408
# Epoch 473, loss 0.0401
# Epoch 474, loss 0.0395
# Epoch 475, loss 0.0389
# Epoch 476, loss 0.0383
# Epoch 477, loss 0.0376
# Epoch 478, loss 0.0371
# Epoch 479, loss 0.0366
# Epoch 480, loss 0.0360
# Epoch 481, loss 0.0353
# Epoch 482, loss 0.0349
# Epoch 483, loss 0.0343
# Epoch 484, loss 0.0337
# Epoch 485, loss 0.0332
# Epoch 486, loss 0.0327
# Epoch 487, loss 0.0322
# Epoch 488, loss 0.0317
# Epoch 489, loss 0.0313
# Epoch 490, loss 0.0308
# Epoch 491, loss 0.0302
# Epoch 492, loss 0.0298
# Epoch 493, loss 0.0292
# Epoch 494, loss 0.0288
# Epoch 495, loss 0.0283
# Epoch 496, loss 0.0278
# Epoch 497, loss 0.0275
# Epoch 498, loss 0.0270
# Epoch 499, loss 0.0266

# %% [markdown]
# ### Finish Training

# %% [markdown]
# ### Plot Loss

# %%
plt.title('cross entropy averaged over minibatches')
plt.plot(epoch_losses)
plt.show()

# %%
print(model.layers[0].apply_mod.linear.weight.size())
print(model.layers[1].apply_mod.linear.weight.size())
model.classify.weight.size()
# Out:
# torch.Size([256, 1])
# torch.Size([256, 256])
# torch.Size([4, 256])

# %% [markdown]
# ### Get Testset data

# %%
testset = []
test_labels = []
test_dir = 'test_data'

testing_idx_1=[]
testing_idx_2=[]
testing_idx_3=[]
testing_idx_4=[]
for i in test_idx:
    testing_idx_1.append(i)
    testing_idx_2.append(i)
    testing_idx_3.append(i)
    testing_idx_4.append(i)
      
# print(testing_idx_1)
# print(training_idx_1)
# print(testing_idx_2)
# print(training_idx_2)
# print(testing_idx_3)
# print(training_idx_3)
# print(testing_idx_4)
# print(training_idx_4)

# %% [markdown]
# ### Random Sample Nodes and Edges for Testing

# %% [markdown]
# ## Set Percentage Keep

# %%
pct_keep = 0.95

# %%
for idx in range(len(testing_idx_1)):
    node_list=[]
    edge_list=[]
    label_list=[]
    node_list2=[]
    edge_list2=[]
    label_list2=[]
    node_list3=[]
    edge_list3=[]
    label_list3=[]
    node_list4=[]
    edge_list4=[]
    label_list4=[]
    for j in ["node_list","edge_list","graph_label"]:
        filename = "rca_"+str(testing_idx_1[idx])+"bit"+j+'.csv'
        filename2 = "cla_"+str(testing_idx_2[idx])+"bit"+j+'.csv'
        filename3 = "csa_"+str(testing_idx_3[idx])+"bit"+j+'.csv'
        filename4 = "CSkipA_"+str(testing_idx_4[idx])+"bit"+j+'.csv'
        
        if(filename.find("node_list")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                node_list = list(reader)
                
        if(filename.find("edge_list")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list = list(reader)
        if(filename.find("graph_label")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                label_list = list(reader)
        if(filename.find("gate_type")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type = list(reader)
        
        if(filename2.find("node_list")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                node_list2 = list(reader)
                
        if(filename2.find("edge_list")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list2 = list(reader)
        if(filename2.find("graph_label")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                label_list2 = list(reader)
        if(filename2.find("gate_type")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type2 = list(reader)
        if(filename3.find("node_list")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                node_list3 = list(reader)
                
        if(filename3.find("edge_list")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list3 = list(reader)
        if(filename3.find("graph_label")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                label_list3 = list(reader)
        if(filename3.find("gate_type")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type3 = list(reader)
        if(filename4.find("node_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                node_list4 = list(reader)
                
        if(filename4.find("edge_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list4 = list(reader)
        if(filename4.find("graph_label")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                label_list4 = list(reader)
        if(filename4.find("gate_type")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type4 = list(reader)
    
    #randomly sample edges but keep all nodes
    
#     node_list_keep = random.sample(node_list,int(len(node_list)*pct_keep))
    node_list_keep = node_list
    edge_list_keep = random.sample(edge_list,int(len(edge_list)*pct_keep))
#     node_list2_keep = random.sample(node_list2,int(len(node_list2)*pct_keep))
    node_list2_keep = node_list2
    edge_list2_keep = random.sample(edge_list2,int(len(edge_list2)*pct_keep))
#     node_list3_keep = random.sample(node_list3,int(len(node_list3)*pct_keep))
    node_list3_keep = node_list3
    edge_list3_keep = random.sample(edge_list3,int(len(edge_list3)*pct_keep))
#     node_list4_keep = random.sample(node_list4,int(len(node_list4)*pct_keep))
    node_list4_keep = node_list4
    edge_list4_keep = random.sample(edge_list4,int(len(edge_list4)*pct_keep))
    
    #create dgl graph
    g=build_circuit_graph_undirected(node_list_keep,edge_list_keep)
    testset.append(g)
    test_labels.append(label_list[0])
    g2=build_circuit_graph_undirected(node_list2_keep,edge_list2_keep)
    testset.append(g2)
    test_labels.append(label_list2[0])
    g3=build_circuit_graph_undirected(node_list3_keep,edge_list3_keep)
    testset.append(g3)
    test_labels.append(label_list3[0])
    g4=build_circuit_graph_undirected(node_list4_keep,edge_list4_keep)
    testset.append(g4)
    test_labels.append(label_list4[0])

for i in test_labels:
    i[0] = int(i[0])

# print(test_labels)

# %%
##apply random shuffle on the testset    
np.random.seed(0)
randomize = np.arange(len(testset))
np.random.shuffle(randomize)
testset_shuffled=[]
test_labels_shuffled=[]
for i in range (len(randomize)):
    test_labels_shuffled.append(test_labels[randomize[i]])
    testset_shuffled.append(testset[randomize[i]])

# %% [markdown]
# ### Test on Testset

# %%
model.eval()
test_bg = dgl.batch(testset_shuffled)
test_labels = torch.tensor(test_labels_shuffled).float().view(-1, 1).cuda()
probs_Y = torch.softmax(model(test_bg), 1)

sampled_Y = torch.multinomial(probs_Y, 1)
argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)
print('Accuracy of sampled predictions on the test set: {:.4f}%'.format(
    (test_labels == sampled_Y.float()).sum().item() / len(test_labels) * 100))
print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
    (test_labels == argmax_Y.float()).sum().item() / len(test_labels) * 100))

# zip(model(test_bg),(test_labels))
# for i1,i2 in zip(probs_Y,(test_labels)):
#     print(i1,i2)
# print(torch.max(probs_Y, 1))
# Out:
# Accuracy of sampled predictions on the test set: 79.8387%
# Accuracy of argmax predictions on the test set: 74.193548%

# %% [markdown]
# ## Finish Testing

# %%
# error = (test_labels != argmax_Y.float()).nonzero()

# %% [markdown]
# ## Get Error Items

# %%
error = (test_labels != argmax_Y.float()).nonzero()
print('Total', len(error),'errors out of',len(test_idx)*4,'test data')
for i in error.cpu().numpy():
    error_idx= i [0]
    print(probs_Y[error_idx],test_labels[error_idx])
#     print(i[0])
# Out:
# Total 32 errors out of 124 test data
# tensor([2.2890e-01, 6.8365e-01, 2.2870e-07, 8.7449e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3.8182e-01, 4.5450e-01, 1.0227e-06, 1.6368e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([4.9008e-02, 9.4888e-01, 2.7539e-09, 2.1142e-03], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([4.9169e-01, 2.5773e-01, 4.6042e-06, 2.5057e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3.7938e-01, 4.6102e-01, 9.6074e-07, 1.5960e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([1.0261e-05, 9.9999e-01, 1.2584e-16, 4.2276e-08], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([2.], device='cuda:0')
# tensor([5.3785e-01, 2.4586e-01, 1.9455e-06, 2.1629e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.1137e-01, 3.1646e-01, 2.7969e-06, 1.7216e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.3110e-01, 3.1815e-01, 9.6947e-07, 1.5075e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([4.6043e-01, 3.2105e-01, 1.3122e-06, 2.1852e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([1.3947e-02, 9.8588e-01, 4.0774e-11, 1.7470e-04], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.6678e-01, 3.1524e-01, 1.3098e-06, 1.1798e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([2.0368e-01, 6.6718e-01, 1.0998e-06, 1.2914e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([6.1341e-01, 1.3023e-01, 5.9768e-06, 2.5635e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3.6330e-01, 6.0357e-01, 1.6274e-07, 3.3132e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([1.1805e-01, 8.7567e-01, 5.6739e-09, 6.2805e-03], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.8618e-01, 2.2405e-01, 2.4636e-06, 1.8976e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([7.9036e-02, 9.0563e-01, 1.7259e-08, 1.5336e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.2673e-01, 3.3092e-01, 1.7806e-06, 1.4235e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3.4075e-01, 6.0736e-01, 4.0379e-07, 5.1891e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([2.7799e-01, 6.8537e-01, 1.0546e-07, 3.6638e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3.6094e-01, 5.7363e-01, 3.0934e-07, 6.5434e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.3303e-01, 2.5119e-01, 2.3845e-06, 2.1577e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([2.4713e-01, 7.1091e-01, 3.9977e-07, 4.1956e-02], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3.9803e-01, 4.2448e-01, 1.3513e-06, 1.7749e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([5.2002e-01, 3.5909e-01, 1.3098e-06, 1.2088e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([4.4420e-01, 3.9050e-01, 1.0785e-06, 1.6529e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([3.], device='cuda:0')
# tensor([3