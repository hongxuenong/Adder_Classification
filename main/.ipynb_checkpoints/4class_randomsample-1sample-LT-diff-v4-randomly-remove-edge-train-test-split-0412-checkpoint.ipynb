# %%
# %matplotlib inline

# %% [markdown]
# ## Setup GPU Device

# %%
import random

# %%
import os
#Set GPU IDs for training:
os.environ["CUDA_VISIBLE_DEVICES"] = '3'

# %%
import dgl
def build_circuit_graph_undirected(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(src, dst)
    g.add_edges(dst, src)
    return g

def build_circuit_graph_directed_sd(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(src, dst)
    return g

def build_circuit_graph_directed_ds(node_list,edge_list):
    g = dgl.DGLGraph()
    g.add_nodes(len(node_list))
    src, dst = tuple(zip(*edge_list))
    g.add_edges(dst, src)
    return g

# %% [markdown]
# ### Choose Number of Training Samples

# %% [markdown]
# ### Train Test Split

# %%
import random
random.seed(0)
training_size = 30
training_idx = random.sample(list(range(5,65)), training_size) #exclude 4-bit adders
test_idx = [item for item in list(range(5,65)) if item not in training_idx]

# %% [markdown]
# ## Pick Training Data

# %%
import os
import matplotlib.pyplot as plt
import networkx as nx
import csv
import numpy as np
dir = '/home/gpu-user-02/hdd/LT-user/Adder_Classification/main/preprocessing/processed_training_data'

trainset=[]
labels=[]
#for filename in os.listdir(dir):
np.random.seed(1)
sample_size = 10
# training_idx = np.random.randint(4,64,10)
training_idx_1 = np.random.choice(training_idx, size=sample_size, replace=False)
# training_idx_2 = np.random.choice(training_idx, size=sample_size, replace=False)
# training_idx_3 = np.random.choice(training_idx, size=sample_size, replace=False)
# training_idx_4 = np.random.choice(training_idx, size=sample_size, replace=False)

training_idx_2 = training_idx_1
training_idx_3 = training_idx_1
training_idx_4 = training_idx_1
# training_idx_1 = [6]
# training_idx_2 = [6]
# training_idx_3 = [6]
# training_idx_4 = [6]
print(training_idx_1,training_idx_2,training_idx_3,training_idx_4)
# Out:
# [23 58 24 11 18 44  9 61 54 39] [23 58 24 11 18 44  9 61 54 39] [23 58 24 11 18 44  9 61 54 39] [23 58 24 11 18 44  9 61 54 39]

# %% [markdown]
# ### Prepare Training and Test Data

# %%
for idx in range(len(training_idx_1)):
    node_list=[]
    edge_list=[]
    label_list=[]
    node_list2=[]
    edge_list2=[]
    label_list2=[]
    node_list3=[]
    edge_list3=[]
    label_list3=[]
    node_list4=[]
    edge_list4=[]
    label_list4=[]
    for j in ["node_list","edge_list","graph_label"]:
        filename = "rca_"+str(training_idx_1[idx])+"bit"+j+'.csv'
        filename2 = "cla_"+str(training_idx_2[idx])+"bit"+j+'.csv'
        filename3 = "csa_"+str(training_idx_3[idx])+"bit"+j+'.csv'
        filename4 = "CSkipA_"+str(training_idx_4[idx])+"bit"+j+'.csv'
        if(filename.find("node_list")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                node_list = list(reader)
                
        if(filename.find("edge_list")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list = list(reader)
        if(filename.find("graph_label")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                label_list = list(reader)
        if(filename.find("gate_type")>=0):
            with open(dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type = list(reader)
        
        if(filename2.find("node_list")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                node_list2 = list(reader)
                
        if(filename2.find("edge_list")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list2 = list(reader)
        if(filename2.find("graph_label")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                label_list2 = list(reader)
        if(filename2.find("gate_type")>=0):
            with open(dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type2 = list(reader)
        
        if(filename3.find("node_list")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                node_list3 = list(reader)
                
        if(filename3.find("edge_list")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list3 = list(reader)
        if(filename3.find("graph_label")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                label_list3 = list(reader)
        if(filename3.find("gate_type")>=0):
            with open(dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type3 = list(reader)
        if(filename4.find("node_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                node_list4 = list(reader)
                
        if(filename4.find("edge_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list4 = list(reader)
        if(filename4.find("graph_label")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                label_list4 = list(reader)
        if(filename4.find("gate_type")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type4 = list(reader)
    #create dgl graph
    g=build_circuit_graph_undirected(node_list,edge_list)
    trainset.append(g)
    labels.append(label_list[0])
    g2=build_circuit_graph_undirected(node_list2,edge_list2)
    trainset.append(g2)
    labels.append(label_list2[0])
    g3=build_circuit_graph_undirected(node_list3,edge_list3)
    trainset.append(g3)
    labels.append(label_list3[0])
    g4=build_circuit_graph_undirected(node_list4,edge_list4)
    trainset.append(g4)
    labels.append(label_list4[0])

for i in labels:
    i[0] = int(i[0])

print(labels)
# Out:
# [[1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3], [1], [0], [2], [3]]

# %% [markdown]
# ### Visualize Training Data

# %%
# graph = trainset[14]
# label=labels[14][0]

# fig, ax = plt.subplots()
# G=graph.to_networkx()
# pos=nx.spring_layout(G)
# nx.draw(G,pos)
# nx.draw_networkx_labels(G,pos, ax=ax)
# ax.set_title('Class: {:f}'.format(label))
# plt.show()

# %% [markdown]
# ### Apply random shuffle to training set

# %%
##apply random shuffle on the trainset
np.random.seed(0)
randomize = np.arange(len(trainset))
np.random.shuffle(randomize)
labels_shuffled=[]
trainset_shuffled=[]
for i in range (len(randomize)):
    labels_shuffled.append(labels[randomize[i]])
    trainset_shuffled.append(trainset[randomize[i]])

# %%
len(trainset_shuffled)
# Out:
# 40

# %%
import dgl

def collate(samples):
    # The input `samples` is a list of pairs
    #  (graph, label).
    graphs, labels = map(list, zip(*samples))
    batched_graph = dgl.batch(graphs)
    return batched_graph, torch.tensor(labels)

# %%
import dgl.function as fn
import torch
import torch.nn as nn

# Sends a message of node feature h.
msg = fn.copy_src(src='h', out='m')

def reduce(nodes):
    """Take an average over all neighbor node features hu and use it to
    overwrite the original node feature."""
    accum = torch.mean(nodes.mailbox['m'], 1)
    return {'h': accum}

class NodeApplyModule(nn.Module):
    """Update the node feature hv with ReLU(Whv+b)."""
    def __init__(self, in_feats, out_feats, activation):
        super(NodeApplyModule, self).__init__()
        self.linear = nn.Linear(in_feats, out_feats)
        self.activation = activation

    def forward(self, node):
        h = self.linear(node.data['h'])
        h = self.activation(h)
        return {'h' : h}

class GCN(nn.Module):
    def __init__(self, in_feats, out_feats, activation):
        super(GCN, self).__init__()
        self.apply_mod = NodeApplyModule(in_feats, out_feats, activation)

    def forward(self, g, feature):
        # Initialize the node features with h.
        g.ndata['h'] = feature
        g.update_all(msg, reduce)
        g.apply_nodes(func=self.apply_mod)
        return g.ndata.pop('h')

# %% [markdown]
# ### Readout and classification

# %%
import torch.nn.functional as F

class Classifier(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_classes):
        super(Classifier, self).__init__()

        self.layers = nn.ModuleList([
            GCN(in_dim, hidden_dim, F.relu),
            GCN(hidden_dim, hidden_dim, F.relu)])
        self.classify = nn.Linear(hidden_dim, n_classes)

    def forward(self, g):
        # For undirected graphs, in_degree is the same as
        # out_degree.
        h = g.in_degrees().view(-1, 1).float().cuda()
        for conv in self.layers:
            h = conv(g, h)
        g.ndata['h'] = h
        hg = dgl.mean_nodes(g, 'h')
        return self.classify(hg)

# %% [markdown]
# ### Setup and training

# %%
import torch.optim as optim
from torch.utils.data import DataLoader

# %% [markdown]
# ### Make Training Results Deterministic

# %%
# import torch
# torch.manual_seed(0)
# #CuDNN:
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Set Training Epoch

# %%
training_epoch = 500 #original = 1500 for 1 training sample 500 for 20 samples
initial_lr = 0.001

# %%
# Create model
#model = Classifier(1, 256, trainset.num_classes)
import time

model = Classifier(1, 256, 4)
model.cuda()
loss_func = nn.CrossEntropyLoss().cuda()
optimizer = optim.Adam(model.parameters(), lr = initial_lr)
# optimizer = optim.SGD(model.parameters(), lr = initial_lr, momentum=0.9, weight_decay=5e-4)

model.train()

labels_shuffled = torch.LongTensor(labels_shuffled).cuda()

epoch_losses = []

#start timer:
t0 = time.time()

for epoch in range(training_epoch):
    model.train()
    epoch_loss = 0
    for iter, bg in enumerate(trainset_shuffled):
        prediction=torch.zeros(1,4,dtype=torch.float64).cuda()
        prediction[0] = model(bg)

        loss = loss_func(prediction, labels_shuffled[iter])
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
    epoch_loss /= (iter + 1)
    print('Epoch {}, loss {:.4f}'.format(epoch, epoch_loss))
    epoch_losses.append(epoch_loss)

training_time = time.time() - t0

print('Finished training. Training time = {:.4f} Seconds'.format(training_time))

#     if (epoch%5==0):
#         model.eval()
#         eval_bg = dgl.batch(trainset_shuffled)
#         eval_labels = torch.tensor(labels_shuffled).float().view(-1, 1)
#         probs_Y = torch.softmax(model(eval_bg), 1)
#         argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)

#         print('Accuracy of argmax predictions on the test set: {:4f}%'.format(
#             (eval_labels == argmax_Y.float()).sum().item() / len(eval_labels) * 100))
# Out:
# Epoch 0, loss 1.6411
# Epoch 1, loss 1.4679
# Epoch 2, loss 1.4465
# Epoch 3, loss 1.4272
# Epoch 4, loss 1.4078
# Epoch 5, loss 1.3907
# Epoch 6, loss 1.3904
# Epoch 7, loss 1.3751
# Epoch 8, loss 1.3864
# Epoch 9, loss 1.3303
# Epoch 10, loss 1.3148
# Epoch 11, loss 1.2927
# Epoch 12, loss 1.2719
# Epoch 13, loss 1.2472
# Epoch 14, loss 1.1675
# Epoch 15, loss 1.1092
# Epoch 16, loss 1.1519
# Epoch 17, loss 1.0610
# Epoch 18, loss 1.0079
# Epoch 19, loss 0.9861
# Epoch 20, loss 0.9797
# Epoch 21, loss 0.9512
# Epoch 22, loss 0.9485
# Epoch 23, loss 0.9280
# Epoch 24, loss 0.9236
# Epoch 25, loss 0.9200
# Epoch 26, loss 0.9076
# Epoch 27, loss 0.8990
# Epoch 28, loss 0.8887
# Epoch 29, loss 0.8788
# Epoch 30, loss 0.8710
# Epoch 31, loss 0.8630
# Epoch 32, loss 0.9226
# Epoch 33, loss 0.8356
# Epoch 34, loss 0.8358
# Epoch 35, loss 0.8314
# Epoch 36, loss 0.8237
# Epoch 37, loss 0.9813
# Epoch 38, loss 0.8093
# Epoch 39, loss 0.7951
# Epoch 40, loss 0.7857
# Epoch 41, loss 0.7729
# Epoch 42, loss 0.7659
# Epoch 43, loss 0.7709
# Epoch 44, loss 0.7649
# Epoch 45, loss 0.7573
# Epoch 46, loss 0.7502
# Epoch 47, loss 0.7412
# Epoch 48, loss 0.7336
# Epoch 49, loss 0.7249
# Epoch 50, loss 0.6721
# Epoch 51, loss 0.6851
# Epoch 52, loss 0.6969
# Epoch 53, loss 0.6930
# Epoch 54, loss 0.6852
# Epoch 55, loss 0.6762
# Epoch 56, loss 0.6672
# Epoch 57, loss 0.6578
# Epoch 58, loss 0.6494
# Epoch 59, loss 0.6406
# Epoch 60, loss 0.6314
# Epoch 61, loss 0.6211
# Epoch 62, loss 0.6184
# Epoch 63, loss 0.6016
# Epoch 64, loss 0.5884
# Epoch 65, loss 0.5919
# Epoch 66, loss 0.5820
# Epoch 67, loss 0.5734
# Epoch 68, loss 0.5639
# Epoch 69, loss 0.5522
# Epoch 70, loss 0.5409
# Epoch 71, loss 0.5317
# Epoch 72, loss 0.5217
# Epoch 73, loss 0.5111
# Epoch 74, loss 0.5010
# Epoch 75, loss 0.4913
# Epoch 76, loss 0.4817
# Epoch 77, loss 0.4712
# Epoch 78, loss 0.4612
# Epoch 79, loss 0.4506
# Epoch 80, loss 0.4404
# Epoch 81, loss 0.4308
# Epoch 82, loss 0.4205
# Epoch 83, loss 0.4106
# Epoch 84, loss 0.3993
# Epoch 85, loss 0.3883
# Epoch 86, loss 0.3768
# Epoch 87, loss 0.3653
# Epoch 88, loss 0.3547
# Epoch 89, loss 0.3438
# Epoch 90, loss 0.3332
# Epoch 91, loss 0.3234
# Epoch 92, loss 0.3136
# Epoch 93, loss 0.3043
# Epoch 94, loss 0.2957
# Epoch 95, loss 0.2874
# Epoch 96, loss 0.2796
# Epoch 97, loss 0.2715
# Epoch 98, loss 0.2639
# Epoch 99, loss 0.2564
# Epoch 100, loss 0.2491
# Epoch 101, loss 0.2424
# Epoch 102, loss 0.2356
# Epoch 103, loss 0.2290
# Epoch 104, loss 0.2224
# Epoch 105, loss 0.2161
# Epoch 106, loss 0.2099
# Epoch 107, loss 0.2043
# Epoch 108, loss 0.1989
# Epoch 109, loss 0.1931
# Epoch 110, loss 0.1875
# Epoch 111, loss 0.1827
# Epoch 112, loss 0.1773
# Epoch 113, loss 0.1723
# Epoch 114, loss 0.1674
# Epoch 115, loss 0.1626
# Epoch 116, loss 0.1581
# Epoch 117, loss 0.1537
# Epoch 118, loss 0.1492
# Epoch 119, loss 0.1449
# Epoch 120, loss 0.1412
# Epoch 121, loss 0.1371
# Epoch 122, loss 0.1337
# Epoch 123, loss 0.1297
# Epoch 124, loss 0.1262
# Epoch 125, loss 0.1222
# Epoch 126, loss 0.1185
# Epoch 127, loss 0.1147
# Epoch 128, loss 0.1117
# Epoch 129, loss 0.1085
# Epoch 130, loss 0.1053
# Epoch 131, loss 0.1023
# Epoch 132, loss 0.0995
# Epoch 133, loss 0.0966
# Epoch 134, loss 0.0940
# Epoch 135, loss 0.0916
# Epoch 136, loss 0.0894
# Epoch 137, loss 0.0873
# Epoch 138, loss 0.0852
# Epoch 139, loss 0.0833
# Epoch 140, loss 0.0815
# Epoch 141, loss 0.0796
# Epoch 142, loss 0.0778
# Epoch 143, loss 0.0762
# Epoch 144, loss 0.0747
# Epoch 145, loss 0.0731
# Epoch 146, loss 0.0717
# Epoch 147, loss 0.0703
# Epoch 148, loss 0.0690
# Epoch 149, loss 0.0676
# Epoch 150, loss 0.0661
# Epoch 151, loss 0.0646
# Epoch 152, loss 0.0633
# Epoch 153, loss 0.0620
# Epoch 154, loss 0.0607
# Epoch 155, loss 0.0596
# Epoch 156, loss 0.0585
# Epoch 157, loss 0.0575
# Epoch 158, loss 0.0566
# Epoch 159, loss 0.0557
# Epoch 160, loss 0.0546
# Epoch 161, loss 0.0536
# Epoch 162, loss 0.0526
# Epoch 163, loss 0.0511
# Epoch 164, loss 0.0494
# Epoch 165, loss 0.0478
# Epoch 166, loss 0.0462
# Epoch 167, loss 0.0443
# Epoch 168, loss 0.0429
# Epoch 169, loss 0.0418
# Epoch 170, loss 0.0409
# Epoch 171, loss 0.0402
# Epoch 172, loss 0.0397
# Epoch 173, loss 0.0394
# Epoch 174, loss 0.0394
# Epoch 175, loss 0.0401
# Epoch 176, loss 0.0432
# Epoch 177, loss 0.0712
# Epoch 178, loss 0.2406
# Epoch 179, loss 0.3910
# Epoch 180, loss 0.1840
# Epoch 181, loss 0.0597
# Epoch 182, loss 0.0356
# Epoch 183, loss 0.0308
# Epoch 184, loss 0.0295
# Epoch 185, loss 0.0286
# Epoch 186, loss 0.0279
# Epoch 187, loss 0.0272
# Epoch 188, loss 0.0266
# Epoch 189, loss 0.0261
# Epoch 190, loss 0.0255
# Epoch 191, loss 0.0250
# Epoch 192, loss 0.0245
# Epoch 193, loss 0.0240
# Epoch 194, loss 0.0236
# Epoch 195, loss 0.0231
# Epoch 196, loss 0.0227
# Epoch 197, loss 0.0223
# Epoch 198, loss 0.0219
# Epoch 199, loss 0.0215
# Epoch 200, loss 0.0211
# Epoch 201, loss 0.0207
# Epoch 202, loss 0.0203
# Epoch 203, loss 0.0199
# Epoch 204, loss 0.0195
# Epoch 205, loss 0.0192
# Epoch 206, loss 0.0188
# Epoch 207, loss 0.0185
# Epoch 208, loss 0.0182
# Epoch 209, loss 0.0179
# Epoch 210, loss 0.0176
# Epoch 211, loss 0.0173
# Epoch 212, loss 0.0170
# Epoch 213, loss 0.0168
# Epoch 214, loss 0.0165
# Epoch 215, loss 0.0162
# Epoch 216, loss 0.0160
# Epoch 217, loss 0.0157
# Epoch 218, loss 0.0155
# Epoch 219, loss 0.0152
# Epoch 220, loss 0.0150
# Epoch 221, loss 0.0147
# Epoch 222, loss 0.0145
# Epoch 223, loss 0.0143
# Epoch 224, loss 0.0140
# Epoch 225, loss 0.0138
# Epoch 226, loss 0.0136
# Epoch 227, loss 0.0134
# Epoch 228, loss 0.0132
# Epoch 229, loss 0.0129
# Epoch 230, loss 0.0127
# Epoch 231, loss 0.0125
# Epoch 232, loss 0.0123
# Epoch 233, loss 0.0122
# Epoch 234, loss 0.0120
# Epoch 235, loss 0.0118
# Epoch 236, loss 0.0116
# Epoch 237, loss 0.0114
# Epoch 238, loss 0.0112
# Epoch 239, loss 0.0110
# Epoch 240, loss 0.0109
# Epoch 241, loss 0.0107
# Epoch 242, loss 0.0105
# Epoch 243, loss 0.0104
# Epoch 244, loss 0.0102
# Epoch 245, loss 0.0101
# Epoch 246, loss 0.0099
# Epoch 247, loss 0.0098
# Epoch 248, loss 0.0096
# Epoch 249, loss 0.0095
# Epoch 250, loss 0.0094
# Epoch 251, loss 0.0092
# Epoch 252, loss 0.0091
# Epoch 253, loss 0.0089
# Epoch 254, loss 0.0088
# Epoch 255, loss 0.0087
# Epoch 256, loss 0.0086
# Epoch 257, loss 0.0085
# Epoch 258, loss 0.0084
# Epoch 259, loss 0.0084
# Epoch 260, loss 0.0083
# Epoch 261, loss 0.0083
# Epoch 262, loss 0.0086
# Epoch 263, loss 0.0160
# Epoch 264, loss 1.0087
# Epoch 265, loss 0.7302
# Epoch 266, loss 0.0700
# Epoch 267, loss 0.0158
# Epoch 268, loss 0.0140
# Epoch 269, loss 0.0135
# Epoch 270, loss 0.0129
# Epoch 271, loss 0.0124
# Epoch 272, loss 0.0120
# Epoch 273, loss 0.0116
# Epoch 274, loss 0.0112
# Epoch 275, loss 0.0109
# Epoch 276, loss 0.0106
# Epoch 277, loss 0.0103
# Epoch 278, loss 0.0101
# Epoch 279, loss 0.0099
# Epoch 280, loss 0.0097
# Epoch 281, loss 0.0095
# Epoch 282, loss 0.0092
# Epoch 283, loss 0.0090
# Epoch 284, loss 0.0088
# Epoch 285, loss 0.0087
# Epoch 286, loss 0.0085
# Epoch 287, loss 0.0083
# Epoch 288, loss 0.0081
# Epoch 289, loss 0.0074
# Epoch 290, loss 0.0075
# Epoch 291, loss 0.0076
# Epoch 292, loss 0.0075
# Epoch 293, loss 0.0074
# Epoch 294, loss 0.0073
# Epoch 295, loss 0.0072
# Epoch 296, loss 0.0070
# Epoch 297, loss 0.0069
# Epoch 298, loss 0.0068
# Epoch 299, loss 0.0067
# Epoch 300, loss 0.0065
# Epoch 301, loss 0.0064
# Epoch 302, loss 0.0063
# Epoch 303, loss 0.0062
# Epoch 304, loss 0.0061
# Epoch 305, loss 0.0060
# Epoch 306, loss 0.0059
# Epoch 307, loss 0.0058
# Epoch 308, loss 0.0057
# Epoch 309, loss 0.0056
# Epoch 310, loss 0.0055
# Epoch 311, loss 0.0054
# Epoch 312, loss 0.0054
# Epoch 313, loss 0.0053
# Epoch 314, loss 0.0052
# Epoch 315, loss 0.0051
# Epoch 316, loss 0.0051
# Epoch 317, loss 0.0050
# Epoch 318, loss 0.0049
# Epoch 319, loss 0.0048
# Epoch 320, loss 0.0048
# Epoch 321, loss 0.0047
# Epoch 322, loss 0.0047
# Epoch 323, loss 0.0046
# Epoch 324, loss 0.0045
# Epoch 325, loss 0.0046
# Epoch 326, loss 0.0045
# Epoch 327, loss 0.0044
# Epoch 328, loss 0.0043
# Epoch 329, loss 0.0043
# Epoch 330, loss 0.0042
# Epoch 331, loss 0.0042
# Epoch 332, loss 0.0041
# Epoch 333, loss 0.0041
# Epoch 334, loss 0.0040
# Epoch 335, loss 0.0040
# Epoch 336, loss 0.0039
# Epoch 337, loss 0.0039
# Epoch 338, loss 0.0038
# Epoch 339, loss 0.0038
# Epoch 340, loss 0.0037
# Epoch 341, loss 0.0037
# Epoch 342, loss 0.0036
# Epoch 343, loss 0.0036
# Epoch 344, loss 0.0035
# Epoch 345, loss 0.0035
# Epoch 346, loss 0.0034
# Epoch 347, loss 0.0034
# Epoch 348, loss 0.0033
# Epoch 349, loss 0.0033
# Epoch 350, loss 0.0032
# Epoch 351, loss 0.0032
# Epoch 352, loss 0.0031
# Epoch 353, loss 0.0031
# Epoch 354, loss 0.0030
# Epoch 355, loss 0.0030
# Epoch 356, loss 0.0029
# Epoch 357, loss 0.0029
# Epoch 358, loss 0.0028
# Epoch 359, loss 0.0028
# Epoch 360, loss 0.0027
# Epoch 361, loss 0.0027
# Epoch 362, loss 0.0027
# Epoch 363, loss 0.0026
# Epoch 364, loss 0.0026
# Epoch 365, loss 0.0025
# Epoch 366, loss 0.0025
# Epoch 367, loss 0.0025
# Epoch 368, loss 0.0024
# Epoch 369, loss 0.0024
# Epoch 370, loss 0.0023
# Epoch 371, loss 0.0023
# Epoch 372, loss 0.0023
# Epoch 373, loss 0.0022
# Epoch 374, loss 0.0022
# Epoch 375, loss 0.0021
# Epoch 376, loss 0.0021
# Epoch 377, loss 0.0021
# Epoch 378, loss 0.0020
# Epoch 379, loss 0.0020
# Epoch 380, loss 0.0020
# Epoch 381, loss 0.0019
# Epoch 382, loss 0.0019
# Epoch 383, loss 0.0019
# Epoch 384, loss 0.0019
# Epoch 385, loss 0.0018
# Epoch 386, loss 0.0018
# Epoch 387, loss 0.0018
# Epoch 388, loss 0.0017
# Epoch 389, loss 0.0017
# Epoch 390, loss 0.0017
# Epoch 391, loss 0.0017
# Epoch 392, loss 0.0016
# Epoch 393, loss 0.0024
# Epoch 394, loss 0.0022
# Epoch 395, loss 0.0016
# Epoch 396, loss 0.0015
# Epoch 397, loss 0.0015
# Epoch 398, loss 0.0015
# Epoch 399, loss 0.0015
# Epoch 400, loss 0.0014
# Epoch 401, loss 0.0014
# Epoch 402, loss 0.0014
# Epoch 403, loss 0.0014
# Epoch 404, loss 0.0013
# Epoch 405, loss 0.0013
# Epoch 406, loss 0.0013
# Epoch 407, loss 0.0013
# Epoch 408, loss 0.0013
# Epoch 409, loss 0.0012
# Epoch 410, loss 0.0012
# Epoch 411, loss 0.0012
# Epoch 412, loss 0.0012
# Epoch 413, loss 0.0012
# Epoch 414, loss 0.0012
# Epoch 415, loss 0.0011
# Epoch 416, loss 0.0011
# Epoch 417, loss 0.0011
# Epoch 418, loss 0.0011
# Epoch 419, loss 0.0011
# Epoch 420, loss 0.0010
# Epoch 421, loss 0.0010
# Epoch 422, loss 0.0010
# Epoch 423, loss 0.0010
# Epoch 424, loss 0.0010
# Epoch 425, loss 0.0010
# Epoch 426, loss 0.0010
# Epoch 427, loss 0.0009
# Epoch 428, loss 0.0009
# Epoch 429, loss 0.0009
# Epoch 430, loss 0.0009
# Epoch 431, loss 0.0009
# Epoch 432, loss 0.0009
# Epoch 433, loss 0.0009
# Epoch 434, loss 0.0008
# Epoch 435, loss 0.0008
# Epoch 436, loss 0.0008
# Epoch 437, loss 0.0008
# Epoch 438, loss 0.0008
# Epoch 439, loss 0.0008
# Epoch 440, loss 0.0008
# Epoch 441, loss 0.0008
# Epoch 442, loss 0.0007
# Epoch 443, loss 0.0007
# Epoch 444, loss 0.0007
# Epoch 445, loss 0.0007
# Epoch 446, loss 0.0007
# Epoch 447, loss 0.0007
# Epoch 448, loss 0.0007
# Epoch 449, loss 0.0006
# Epoch 450, loss 0.0006
# Epoch 451, loss 0.0006
# Epoch 452, loss 0.0006
# Epoch 453, loss 0.0006
# Epoch 454, loss 0.0006
# Epoch 455, loss 0.0006
# Epoch 456, loss 0.0006
# Epoch 457, loss 0.0006
# Epoch 458, loss 0.0006
# Epoch 459, loss 0.0005
# Epoch 460, loss 0.0005
# Epoch 461, loss 0.0005
# Epoch 462, loss 0.0005
# Epoch 463, loss 0.0005
# Epoch 464, loss 0.0005
# Epoch 465, loss 0.0005
# Epoch 466, loss 0.0005
# Epoch 467, loss 0.0005
# Epoch 468, loss 0.0005
# Epoch 469, loss 0.0005
# Epoch 470, loss 0.0004
# Epoch 471, loss 0.0004
# Epoch 472, loss 0.0004
# Epoch 473, loss 0.0004
# Epoch 474, loss 0.0004
# Epoch 475, loss 0.0004
# Epoch 476, loss 0.0004
# Epoch 477, loss 0.0004
# Epoch 478, loss 0.0004
# Epoch 479, loss 0.0004
# Epoch 480, loss 0.0004
# Epoch 481, loss 0.0004
# Epoch 482, loss 0.0004
# Epoch 483, loss 0.0004
# Epoch 484, loss 0.0004
# Epoch 485, loss 0.0049
# Epoch 486, loss 1.5786
# Epoch 487, loss 0.1975
# Epoch 488, loss 0.1966
# Epoch 489, loss 0.0369
# Epoch 490, loss 0.0115
# Epoch 491, loss 0.0021
# Epoch 492, loss 0.0012
# Epoch 493, loss 0.0011
# Epoch 494, loss 0.0009
# Epoch 495, loss 0.0008
# Epoch 496, loss 0.0008
# Epoch 497, loss 0.0007
# Epoch 498, loss 0.0007
# Epoch 499, loss 0.0007
# Finished training. Training time = 183.4071 Seconds

# %% [markdown]
# ### Finish Training

# %% [markdown]
# ### Plot Loss

# %%
plt.title('cross entropy averaged over minibatches')
plt.plot(epoch_losses)
plt.show()

# %%
print(model.layers[0].apply_mod.linear.weight.size())
print(model.layers[1].apply_mod.linear.weight.size())
model.classify.weight.size()
# Out:
# torch.Size([256, 1])
# torch.Size([256, 256])
# torch.Size([4, 256])

# %% [markdown]
# ### Get Testset data

# %%
testset = []
test_labels = []
test_dir = dir

testing_idx_1=[]
testing_idx_2=[]
testing_idx_3=[]
testing_idx_4=[]
for i in test_idx:
    testing_idx_1.append(i)
    testing_idx_2.append(i)
    testing_idx_3.append(i)
    testing_idx_4.append(i)
      
# print(testing_idx_1)
# print(training_idx_1)
# print(testing_idx_2)
# print(training_idx_2)
# print(testing_idx_3)
# print(training_idx_3)
# print(testing_idx_4)
# print(training_idx_4)

# %% [markdown]
# ### Random Sample Nodes and Edges for Testing

# %% [markdown]
# ## Set Percentage Keep

# %%
pct_keep = 0.95

# %%
for idx in range(len(testing_idx_1)):
    node_list=[]
    edge_list=[]
    label_list=[]
    node_list2=[]
    edge_list2=[]
    label_list2=[]
    node_list3=[]
    edge_list3=[]
    label_list3=[]
    node_list4=[]
    edge_list4=[]
    label_list4=[]
    for j in ["node_list","edge_list","graph_label"]:
        filename = "rca_"+str(testing_idx_1[idx])+"bit"+j+'.csv'
        filename2 = "cla_"+str(testing_idx_2[idx])+"bit"+j+'.csv'
        filename3 = "csa_"+str(testing_idx_3[idx])+"bit"+j+'.csv'
        filename4 = "CSkipA_"+str(testing_idx_4[idx])+"bit"+j+'.csv'
        
        if(filename.find("node_list")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                node_list = list(reader)
                
        if(filename.find("edge_list")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list = list(reader)
        if(filename.find("graph_label")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                label_list = list(reader)
        if(filename.find("gate_type")>=0):
            with open(test_dir+'/'+filename, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type = list(reader)
        
        if(filename2.find("node_list")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                node_list2 = list(reader)
                
        if(filename2.find("edge_list")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list2 = list(reader)
        if(filename2.find("graph_label")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                label_list2 = list(reader)
        if(filename2.find("gate_type")>=0):
            with open(test_dir+'/'+filename2, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type2 = list(reader)
        if(filename3.find("node_list")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                node_list3 = list(reader)
                
        if(filename3.find("edge_list")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list3 = list(reader)
        if(filename3.find("graph_label")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                label_list3 = list(reader)
        if(filename3.find("gate_type")>=0):
            with open(test_dir+'/'+filename3, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type3 = list(reader)
        if(filename4.find("node_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                node_list4 = list(reader)
                
        if(filename4.find("edge_list")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                edge_list4 = list(reader)
        if(filename4.find("graph_label")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                label_list4 = list(reader)
        if(filename4.find("gate_type")>=0):
            with open(dir+'/'+filename4, 'rt') as fh:
                reader=csv.reader(fh)
                gate_type4 = list(reader)
    
    #randomly sample edges but keep all nodes
    
#     node_list_keep = random.sample(node_list,int(len(node_list)*pct_keep))
    node_list_keep = node_list
    edge_list_keep = random.sample(edge_list,int(len(edge_list)*pct_keep))
#     node_list2_keep = random.sample(node_list2,int(len(node_list2)*pct_keep))
    node_list2_keep = node_list2
    edge_list2_keep = random.sample(edge_list2,int(len(edge_list2)*pct_keep))
#     node_list3_keep = random.sample(node_list3,int(len(node_list3)*pct_keep))
    node_list3_keep = node_list3
    edge_list3_keep = random.sample(edge_list3,int(len(edge_list3)*pct_keep))
#     node_list4_keep = random.sample(node_list4,int(len(node_list4)*pct_keep))
    node_list4_keep = node_list4
    edge_list4_keep = random.sample(edge_list4,int(len(edge_list4)*pct_keep))
    
    #create dgl graph
    g=build_circuit_graph_undirected(node_list_keep,edge_list_keep)
    testset.append(g)
    test_labels.append(label_list[0])
    g2=build_circuit_graph_undirected(node_list2_keep,edge_list2_keep)
    testset.append(g2)
    test_labels.append(label_list2[0])
    g3=build_circuit_graph_undirected(node_list3_keep,edge_list3_keep)
    testset.append(g3)
    test_labels.append(label_list3[0])
    g4=build_circuit_graph_undirected(node_list4_keep,edge_list4_keep)
    testset.append(g4)
    test_labels.append(label_list4[0])

for i in test_labels:
    i[0] = int(i[0])

# print(test_labels)

# %%
##apply random shuffle on the testset    
np.random.seed(0)
randomize = np.arange(len(testset))
np.random.shuffle(randomize)
testset_shuffled=[]
test_labels_shuffled=[]
for i in range (len(randomize)):
    test_labels_shuffled.append(test_labels[randomize[i]])
    testset_shuffled.append(testset[randomize[i]])

# %% [markdown]
# ### Test on Testset

# %%
model.eval()
test_bg = dgl.batch(testset_shuffled)
test_labels_shuffled = torch.tensor(test_labels_shuffled).float().view(-1, 1).cuda()
probs_Y = torch.softmax(model(test_bg), 1)

sampled_Y = torch.multinomial(probs_Y, 1)
argmax_Y = torch.max(probs_Y, 1)[1].view(-1, 1)
print('Accuracy of sampled predictions on the test set: {:.4f}%'.format(
    (test_labels_shuffled == sampled_Y.float()).sum().item() / len(test_labels) * 100))
print('Accuracy of argmax predictions on the test set: {:.4f}%'.format(
    (test_labels_shuffled == argmax_Y.float()).sum().item() / len(test_labels) * 100))

# zip(model(test_bg),(test_labels))
# for i1,i2 in zip(probs_Y,(test_labels)):
#     print(i1,i2)
# print(torch.max(probs_Y, 1))
# Out:
# Accuracy of sampled predictions on the test set: 98.3333%
# Accuracy of argmax predictions on the test set: 98.3333%

# %% [markdown]
# ## Finish Testing

# %% [markdown]
# ## Get Error Items

# %%
error = (test_labels_shuffled != argmax_Y.float()).nonzero()
print('Total', len(error),'errors out of',len(test_idx)*4,'test data')
for i in error.cpu().numpy():
    error_idx= i[0]
    print(probs_Y[error_idx],test_labels_shuffled[error_idx])
#     print(i[0])
# Out:
# Total 2 errors out of 120 test data
# tensor([5.0442e-04, 4.2232e-02, 1.1872e-06, 9.5726e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([2.], device='cuda:0')
# tensor([6.9123e-06, 4.1262e-06, 3.2786e-03, 9.9671e-01], device='cuda:0',
#        grad_fn=<SelectBackward>) tensor([2.], device='cuda:0')

# %%
test_accuracy = '{:4f}'.format((test_labels_shuffled == argmax_Y.float()).sum().item() / len(test_labels) * 100)

# %% [markdown]
# ## Save Trained Model

# %%
from datetime import datetime

dateTimeObj = datetime.now()
 
timestampStr = dateTimeObj.strftime("%d-%b-%Y-%H:%M:%S")
 
print('Current Timestamp : ', timestampStr)
# Out:
# Current Timestamp :  12-Apr-2020-11:27:42

# %%
'4-class-model_{}-samples_{}-epoch_acc-'.format(sample_size,training_epoch)+test_accuracy+'_'+'{}-errs_'.format(len(error))+timestampStr
# Out:
# '4-class-model_10-samples_500-epoch_acc-98.333333_2-errs_12-Apr-2020-11:27:42'

# %%
#set model name:
model_name = '4-class-model_{}-samples_{}-epoch_acc-'.format(sample_size,training_epoch)+test_accuracy+'_'+'{}-errs_'.format(len(error))+timestampStr

SAVE_PATH = '/home/gpu-user-02/hdd/LT-user/Adder_Classification/main/models/' + model_name
torch.save(model.state_dict(), SAVE_PATH)

# %% [markdown]
# ## Load Model

# %%
# model_name = '4class_1Sample_97.580645_0411'

SAVE_PATH = '/home/gpu-user-02/hdd/LT-user/Adder_Classification/main/models/' + model_name
model = Classifier(1, 256, 4)
model.load_state_dict(torch.load(SAVE_PATH))
model.cuda()
model.eval()
# Out:
# Classifier(
#   (layers): ModuleList(
#     (0): GCN(
#       (apply_mod): NodeApplyModule(
#         (linear): Linear(in_features=1, out_features=256, bias=True)
#       )
#     )
#     (1): GCN(
#       (apply_mod): NodeApplyModule(
#         (linear): Linear(in_features=256, out_features=256, bias=True)
#       )
#     )
#   )
#   (classify): Linear(in_features=256, out_features=4, bias=True)
# )

# %%
# (test_labels != argmax_Y.float()).nonzero()

# %% [markdown]
# ## Visualize Activations

# %%
GCN1_act = []
GCN2_act = []
graph_emb = []
final_class = []

def get_activation_1(self,input,output):
#     print(output.size())
    GCN1_act.append(output.data.cpu().numpy())
    
def get_activation_2(self,input,output):
#     print(output.size())
    GCN2_act.append(output.data.cpu().numpy())
    
def get_activation_3(self,input,output):
#     print(output.size())
    graph_emb.append(input[0].cpu().detach().numpy())
    final_class.append(output.data.cpu().numpy())

# %%
h1 = model.layers[0].register_forward_hook(get_activation_1)
h2 = model.layers[1].register_forward_hook(get_activation_2)
h3 = model.classify.register_forward_hook(get_activation_3)

for i in range(len(testset)):
    out = model(testset[i])

# %%
len(GCN1_act),len(GCN2_act),len(graph_emb),len(final_class)
# Out:
# (120, 120, 120, 120)

# %%
GCN1_act_vis_ls = []
GCN2_act_vis_ls = []
graph_emb_vis_ls = []
final_class_vis_ls = []

for i in range(len(GCN1_act)):
    GCN1_act_vis_ls.append(np.expand_dims(np.mean(GCN1_act[i],axis=0),axis=0))
    GCN2_act_vis_ls.append(np.expand_dims(np.mean(GCN2_act[i],axis=0),axis=0))
    graph_emb_vis_ls.append(np.expand_dims(graph_emb[i],axis=0))
    final_class_vis_ls.append(np.expand_dims(final_class[i],axis=0))

# %%
GCN1_act_vis = np.concatenate(GCN1_act_vis_ls, axis=0)
GCN2_act_vis = np.concatenate(GCN2_act_vis_ls, axis=0)
graph_emb_vis = np.concatenate(graph_emb_vis_ls, axis=0)
final_class_vis = np.concatenate(final_class_vis_ls, axis=0)

# %%
GCN1_act_vis.shape,GCN2_act_vis.shape,graph_emb_vis.shape,final_class_vis.shape
# Out:
# ((120, 256), (120, 256), (120, 256), (120, 4))

# %%
# GCN1_act[0].size(),GCN2_act[0].size(),graph_emb[0].size(),final_class[0]

# %%
import tsne
vis1 = tsne.tsne(GCN1_act_vis, 2, 30)
vis2 = tsne.tsne(GCN2_act_vis, 2, 30)
vis3 = tsne.tsne(graph_emb_vis, 2, 30)
vis4 = tsne.tsne(final_class_vis, 2, 30)
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 120...
# Mean value of sigma: 0.716254
# Iteration 10: error is 10.966692
# Iteration 20: error is 7.805412
# Iteration 30: error is 9.165278
# Iteration 40: error is 8.845698
# Iteration 50: error is 9.494474
# Iteration 60: error is 8.739675
# Iteration 70: error is 8.656690
# Iteration 80: error is 8.385483
# Iteration 90: error is 8.631417
# Iteration 100: error is 8.623075
# Iteration 110: error is 0.931291
# Iteration 120: error is 0.689147
# Iteration 130: error is 0.376658
# Iteration 140: error is 0.224534
# Iteration 150: error is 0.095510
# Iteration 160: error is 0.082968
# Iteration 170: error is 0.060733
# Iteration 180: error is 0.052488
# Iteration 190: error is 0.051353
# Iteration 200: error is 0.050001
# Iteration 210: error is 0.048416
# Iteration 220: error is 0.046942
# Iteration 230: error is 0.045821
# Iteration 240: error is 0.045158
# Iteration 250: error is 0.044893
# Iteration 260: error is 0.044767
# Iteration 270: error is 0.044678
# Iteration 280: error is 0.044605
# Iteration 290: error is 0.044536
# Iteration 300: error is 0.044472
# Iteration 310: error is 0.044413
# Iteration 320: error is 0.044357
# Iteration 330: error is 0.044306
# Iteration 340: error is 0.044261
# Iteration 350: error is 0.044216
# Iteration 360: error is 0.044175
# Iteration 370: error is 0.044137
# Iteration 380: error is 0.044101
# Iteration 390: error is 0.044067
# Iteration 400: error is 0.044035
# Iteration 410: error is 0.044004
# Iteration 420: error is 0.043975
# Iteration 430: error is 0.043948
# Iteration 440: error is 0.043921
# Iteration 450: error is 0.043897
# Iteration 460: error is 0.043874
# Iteration 470: error is 0.043851
# Iteration 480: error is 0.043829
# Iteration 490: error is 0.043808
# Iteration 500: error is 0.043787
# Iteration 510: error is 0.043766
# Iteration 520: error is 0.043750
# Iteration 530: error is 0.043735
# Iteration 540: error is 0.043718
# Iteration 550: error is 0.043703
# Iteration 560: error is 0.043686
# Iteration 570: error is 0.043671
# Iteration 580: error is 0.043656
# Iteration 590: error is 0.043641
# Iteration 600: error is 0.043628
# Iteration 610: error is 0.043615
# Iteration 620: error is 0.043602
# Iteration 630: error is 0.043589
# Iteration 640: error is 0.043577
# Iteration 650: error is 0.043565
# Iteration 660: error is 0.043553
# Iteration 670: error is 0.043542
# Iteration 680: error is 0.043531
# Iteration 690: error is 0.043520
# Iteration 700: error is 0.043511
# Iteration 710: error is 0.043502
# Iteration 720: error is 0.043491
# Iteration 730: error is 0.043482
# Iteration 740: error is 0.043474
# Iteration 750: error is 0.043466
# Iteration 760: error is 0.043457
# Iteration 770: error is 0.043448
# Iteration 780: error is 0.043439
# Iteration 790: error is 0.043432
# Iteration 800: error is 0.043424
# Iteration 810: error is 0.043416
# Iteration 820: error is 0.043408
# Iteration 830: error is 0.043402
# Iteration 840: error is 0.043396
# Iteration 850: error is 0.043389
# Iteration 860: error is 0.043382
# Iteration 870: error is 0.043376
# Iteration 880: error is 0.043368
# Iteration 890: error is 0.043363
# Iteration 900: error is 0.043357
# Iteration 910: error is 0.043351
# Iteration 920: error is 0.043345
# Iteration 930: error is 0.043339
# Iteration 940: error is 0.043333
# Iteration 950: error is 0.043327
# Iteration 960: error is 0.043321
# Iteration 970: error is 0.043316
# Iteration 980: error is 0.043310
# Iteration 990: error is 0.043304
# Iteration 1000: error is 0.043300
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 120...
# Mean value of sigma: 3.702221
# Iteration 10: error is 8.291817
# Iteration 20: error is 7.154588
# Iteration 30: error is 8.735730
# Iteration 40: error is 8.038102
# Iteration 50: error is 8.016427
# Iteration 60: error is 7.371243
# Iteration 70: error is 7.776516
# Iteration 80: error is 7.667512
# Iteration 90: error is 7.411635
# Iteration 100: error is 7.408816
# Iteration 110: error is 0.871034
# Iteration 120: error is 0.404884
# Iteration 130: error is 0.106953
# Iteration 140: error is 0.048271
# Iteration 150: error is 0.038082
# Iteration 160: error is 0.035176
# Iteration 170: error is 0.033528
# Iteration 180: error is 0.031800
# Iteration 190: error is 0.029346
# Iteration 200: error is 0.027042
# Iteration 210: error is 0.025733
# Iteration 220: error is 0.025273
# Iteration 230: error is 0.024980
# Iteration 240: error is 0.024713
# Iteration 250: error is 0.024498
# Iteration 260: error is 0.024335
# Iteration 270: error is 0.024211
# Iteration 280: error is 0.024129
# Iteration 290: error is 0.024063
# Iteration 300: error is 0.024010
# Iteration 310: error is 0.023973
# Iteration 320: error is 0.023938
# Iteration 330: error is 0.023920
# Iteration 340: error is 0.023904
# Iteration 350: error is 0.023885
# Iteration 360: error is 0.023869
# Iteration 370: error is 0.023855
# Iteration 380: error is 0.023840
# Iteration 390: error is 0.023825
# Iteration 400: error is 0.023814
# Iteration 410: error is 0.023804
# Iteration 420: error is 0.023793
# Iteration 430: error is 0.023783
# Iteration 440: error is 0.023773
# Iteration 450: error is 0.023764
# Iteration 460: error is 0.023755
# Iteration 470: error is 0.023747
# Iteration 480: error is 0.023739
# Iteration 490: error is 0.023731
# Iteration 500: error is 0.023725
# Iteration 510: error is 0.023718
# Iteration 520: error is 0.023711
# Iteration 530: error is 0.023706
# Iteration 540: error is 0.023702
# Iteration 550: error is 0.023696
# Iteration 560: error is 0.023691
# Iteration 570: error is 0.023687
# Iteration 580: error is 0.023683
# Iteration 590: error is 0.023677
# Iteration 600: error is 0.023673
# Iteration 610: error is 0.023670
# Iteration 620: error is 0.023665
# Iteration 630: error is 0.023661
# Iteration 640: error is 0.023657
# Iteration 650: error is 0.023654
# Iteration 660: error is 0.023650
# Iteration 670: error is 0.023647
# Iteration 680: error is 0.023643
# Iteration 690: error is 0.023640
# Iteration 700: error is 0.023637
# Iteration 710: error is 0.023634
# Iteration 720: error is 0.023631
# Iteration 730: error is 0.023629
# Iteration 740: error is 0.023625
# Iteration 750: error is 0.023623
# Iteration 760: error is 0.023622
# Iteration 770: error is 0.023620
# Iteration 780: error is 0.023617
# Iteration 790: error is 0.023615
# Iteration 800: error is 0.023613
# Iteration 810: error is 0.023610
# Iteration 820: error is 0.023608
# Iteration 830: error is 0.023606
# Iteration 840: error is 0.023604
# Iteration 850: error is 0.023602
# Iteration 860: error is 0.023599
# Iteration 870: error is 0.023597
# Iteration 880: error is 0.023596
# Iteration 890: error is 0.023594
# Iteration 900: error is 0.023593
# Iteration 910: error is 0.023591
# Iteration 920: error is 0.023589
# Iteration 930: error is 0.023587
# Iteration 940: error is 0.023585
# Iteration 950: error is 0.023583
# Iteration 960: error is 0.023582
# Iteration 970: error is 0.023580
# Iteration 980: error is 0.023578
# Iteration 990: error is 0.023577
# Iteration 1000: error is 0.023575
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 120...
# Mean value of sigma: 3.702221
# Iteration 10: error is 10.207233
# Iteration 20: error is 7.669204
# Iteration 30: error is 8.097092
# Iteration 40: error is 7.936260
# Iteration 50: error is 8.026011
# Iteration 60: error is 7.227420
# Iteration 70: error is 7.235708
# Iteration 80: error is 7.278869
# Iteration 90: error is 7.481463
# Iteration 100: error is 7.561945
# Iteration 110: error is 1.057013
# Iteration 120: error is 0.781421
# Iteration 130: error is 0.367906
# Iteration 140: error is 0.114040
# Iteration 150: error is 0.053650
# Iteration 160: error is 0.036139
# Iteration 170: error is 0.032634
# Iteration 180: error is 0.031043
# Iteration 190: error is 0.029927
# Iteration 200: error is 0.028539
# Iteration 210: error is 0.026972
# Iteration 220: error is 0.025925
# Iteration 230: error is 0.025531
# Iteration 240: error is 0.025118
# Iteration 250: error is 0.024896
# Iteration 260: error is 0.024706
# Iteration 270: error is 0.024490
# Iteration 280: error is 0.024276
# Iteration 290: error is 0.024103
# Iteration 300: error is 0.023957
# Iteration 310: error is 0.023853
# Iteration 320: error is 0.023775
# Iteration 330: error is 0.023716
# Iteration 340: error is 0.023679
# Iteration 350: error is 0.023651
# Iteration 360: error is 0.023629
# Iteration 370: error is 0.023614
# Iteration 380: error is 0.023603
# Iteration 390: error is 0.023594
# Iteration 400: error is 0.023587
# Iteration 410: error is 0.023581
# Iteration 420: error is 0.023575
# Iteration 430: error is 0.023569
# Iteration 440: error is 0.023565
# Iteration 450: error is 0.023560
# Iteration 460: error is 0.023555
# Iteration 470: error is 0.023551
# Iteration 480: error is 0.023547
# Iteration 490: error is 0.023542
# Iteration 500: error is 0.023538
# Iteration 510: error is 0.023535
# Iteration 520: error is 0.023531
# Iteration 530: error is 0.023528
# Iteration 540: error is 0.023525
# Iteration 550: error is 0.023522
# Iteration 560: error is 0.023520
# Iteration 570: error is 0.023518
# Iteration 580: error is 0.023515
# Iteration 590: error is 0.023513
# Iteration 600: error is 0.023511
# Iteration 610: error is 0.023508
# Iteration 620: error is 0.023506
# Iteration 630: error is 0.023505
# Iteration 640: error is 0.023502
# Iteration 650: error is 0.023501
# Iteration 660: error is 0.023499
# Iteration 670: error is 0.023497
# Iteration 680: error is 0.023495
# Iteration 690: error is 0.023494
# Iteration 700: error is 0.023492
# Iteration 710: error is 0.023491
# Iteration 720: error is 0.023489
# Iteration 730: error is 0.023488
# Iteration 740: error is 0.023487
# Iteration 750: error is 0.023486
# Iteration 760: error is 0.023484
# Iteration 770: error is 0.023483
# Iteration 780: error is 0.023482
# Iteration 790: error is 0.023481
# Iteration 800: error is 0.023480
# Iteration 810: error is 0.023480
# Iteration 820: error is 0.023479
# Iteration 830: error is 0.023478
# Iteration 840: error is 0.023477
# Iteration 850: error is 0.023476
# Iteration 860: error is 0.023476
# Iteration 870: error is 0.023475
# Iteration 880: error is 0.023474
# Iteration 890: error is 0.023474
# Iteration 900: error is 0.023473
# Iteration 910: error is 0.023473
# Iteration 920: error is 0.023472
# Iteration 930: error is 0.023471
# Iteration 940: error is 0.023471
# Iteration 950: error is 0.023471
# Iteration 960: error is 0.023470
# Iteration 970: error is 0.023470
# Iteration 980: error is 0.023469
# Iteration 990: error is 0.023469
# Iteration 1000: error is 0.023468
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point 0 of 120...
# Mean value of sigma: 12.831533
# Iteration 10: error is 8.597592
# Iteration 20: error is 7.424068
# Iteration 30: error is 8.171462
# Iteration 40: error is 8.503132
# Iteration 50: error is 8.197128
# Iteration 60: error is 8.056161
# Iteration 70: error is 7.649189
# Iteration 80: error is 7.556147
# Iteration 90: error is 7.690026
# Iteration 100: error is 7.887330
# Iteration 110: error is 0.901477
# Iteration 120: error is 0.523908
# Iteration 130: error is 0.191409
# Iteration 140: error is 0.140154
# Iteration 150: error is 0.097718
# Iteration 160: error is 0.044396
# Iteration 170: error is 0.034023
# Iteration 180: error is 0.030375
# Iteration 190: error is 0.029231
# Iteration 200: error is 0.027919
# Iteration 210: error is 0.027098
# Iteration 220: error is 0.026843
# Iteration 230: error is 0.026753
# Iteration 240: error is 0.026681
# Iteration 250: error is 0.026604
# Iteration 260: error is 0.026532
# Iteration 270: error is 0.026473
# Iteration 280: error is 0.026414
# Iteration 290: error is 0.026356
# Iteration 300: error is 0.026304
# Iteration 310: error is 0.026256
# Iteration 320: error is 0.026209
# Iteration 330: error is 0.026164
# Iteration 340: error is 0.026124
# Iteration 350: error is 0.026085
# Iteration 360: error is 0.026049
# Iteration 370: error is 0.026016
# Iteration 380: error is 0.025984
# Iteration 390: error is 0.025953
# Iteration 400: error is 0.025925
# Iteration 410: error is 0.025897
# Iteration 420: error is 0.025872
# Iteration 430: error is 0.025853
# Iteration 440: error is 0.025834
# Iteration 450: error is 0.025813
# Iteration 460: error is 0.025790
# Iteration 470: error is 0.025769
# Iteration 480: error is 0.025753
# Iteration 490: error is 0.025735
# Iteration 500: error is 0.025719
# Iteration 510: error is 0.025703
# Iteration 520: error is 0.025687
# Iteration 530: error is 0.025673
# Iteration 540: error is 0.025659
# Iteration 550: error is 0.025647
# Iteration 560: error is 0.025642
# Iteration 570: error is 0.025624
# Iteration 580: error is 0.025617
# Iteration 590: error is 0.025611
# Iteration 600: error is 0.025604
# Iteration 610: error is 0.025595
# Iteration 620: error is 0.025587
# Iteration 630: error is 0.025579
# Iteration 640: error is 0.025571
# Iteration 650: error is 0.025563
# Iteration 660: error is 0.025556
# Iteration 670: error is 0.025549
# Iteration 680: error is 0.025541
# Iteration 690: error is 0.025535
# Iteration 700: error is 0.025530
# Iteration 710: error is 0.025523
# Iteration 720: error is 0.025517
# Iteration 730: error is 0.025511
# Iteration 740: error is 0.025506
# Iteration 750: error is 0.025500
# Iteration 760: error is 0.025494
# Iteration 770: error is 0.025490
# Iteration 780: error is 0.025485
# Iteration 790: error is 0.025480
# Iteration 800: error is 0.025475
# Iteration 810: error is 0.025470
# Iteration 820: error is 0.025466
# Iteration 830: error is 0.025461
# Iteration 840: error is 0.025457
# Iteration 850: error is 0.025453
# Iteration 860: error is 0.025449
# Iteration 870: error is 0.025445
# Iteration 880: error is 0.025442
# Iteration 890: error is 0.025438
# Iteration 900: error is 0.025435
# Iteration 910: error is 0.025431
# Iteration 920: error is 0.025427
# Iteration 930: error is 0.025424
# Iteration 940: error is 0.025421
# Iteration 950: error is 0.025417
# Iteration 960: error is 0.025414
# Iteration 970: error is 0.025411
# Iteration 980: error is 0.025408
# Iteration 990: error is 0.025405
# Iteration 1000: error is 0.025403

# %%
fig, axs = plt.subplots(2,2,figsize=(15,15))

# color = test_labels.cpu()*85/255

#class 0: cla 'green'
#class 1: rca 'red'
#class 2: csla 'blue'
#class 3: cska 'gold'

color = []
# marker = []

for i in range(len(test_labels)):
    if test_labels[i] == [0]:
        color.append('green')
#         marker.append('.')
    if test_labels[i] == [1]:
        color.append('red')
#         marker.append('^')
    if test_labels[i] == [2]:
        color.append('blue')
#         marker.append('v')
    if test_labels[i] == [3]:
        color.append('gold')
#         marker.append('s')

axs[0,0].set_title('GCN1')
axs[0,1].set_title('GCN2')
axs[1,0].set_title('Graph_emb')
axs[1,1].set_title('Final_class')
for i in range (len(test_labels)):
#     axs[0,0].scatter(vis1[i,0],vis1[i,1],color=(0,color[i],0))
#     axs[0,1].scatter(vis2[i,0],vis2[i,1],color=(0,color[i],0))
#     axs[1,0].scatter(vis3[i,0],vis3[i,1],color=(0,color[i],0))
#     axs[1,1].scatter(vis4[i,0],vis4[i,1],color=(0,color[i],0))
    axs[0,0].scatter(vis1[i,0],vis1[i,1],color=color[i])
    axs[0,1].scatter(vis2[i,0],vis2[i,1],color=color[i])
    axs[1,0].scatter(vis3[i,0],vis3[i,1],color=color[i])
    axs[1,1].scatter(vis4[i,0],vis4[i,1],color=color[i])
#     axs[0,0].scatter(vis1[i,0],vis1[i,1],color=color[i],marker=marker[i])
#     axs[0,1].scatter(vis2[i,0],vis2[i,1],color=color[i],marker=marker[i])
#     axs[1,0].scatter(vis3[i,0],vis3[i,1],color=color[i],marker=marker[i])
#     axs[1,1].scatter(vis4[i,0],vis4[i,1],color=color[i],marker=marker[i])

plt.show()

# %% [markdown]
# ## End
